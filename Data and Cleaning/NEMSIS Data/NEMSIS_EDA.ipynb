# %%
# Import packages
import pandas as pd

# %%
ems_agencies = pd.read_csv('C:\\Users\\jrzem\\OneDrive\\Semester Classwork\\Graduate\\Fall 2025 CMU\\Data Focused Python\\HospiTrack\\Data and Cleaning\\NEMSIS Data\\IL_StateDataSet_Agencies.csv')
hospital_location = pd.read_csv('C:\\Users\\jrzem\\OneDrive\\Semester Classwork\\Graduate\\Fall 2025 CMU\\Data Focused Python\\HospiTrack\\Data and Cleaning\\NEMSIS Data\\IL_StateDataSet_Facilities.csv')

# %%
ems_agencies.head()
# Out:
#    Unique State ID  Number                        Name  Unnamed: 3
# 0             2896    2896         10-33 AMBULANCE LTD         NaN
# 1             8725    8725       1ST RESPONSE EMS INC.         NaN
# 2             8061    8061  A-ADVANTAGE AMBULANCE INC.         NaN
# 3             1399    1399         A-TEC AMBULANCE INC         NaN
# 4             2592    2592        A.M.T. OF CENTRAL IL         NaN

# %%
hospital_location.head()
# Out:
#        Type                                            Name  Location Code  \
# 0  Hospital               Abraham Lincoln Memorial Hospital            578
# 1  Hospital  AMITA Health Adventist Medical Center GlenOaks            239
# 2  Hospital  AMITA Health Adventist Medical Center Hinsdale            241
# 3  Hospital           Adventist La Grange Memorial Hospital            147
# 4  Hospital                    Carle BroMenn Medical Center            615
#
#    Hospital Designations  NPIs  Rm, Suite, or Apt            Street Address  \
# 0                    NaN   NaN                NaN        200 Stahlhut Drive
# 1                    NaN   NaN                NaN       701 Winthrop Avenue
# 2                    NaN   NaN                NaN      120 North Oak Street
# 3                    NaN   NaN                NaN  5101 Willow Springs Road
# 4                    NaN   NaN                NaN      1304 Franklin Avenue
#
# ...
