# %% [markdown]
# # US States County Hospital Data Scraper - COMPREHENSIVE
#
# This notebook scrapes detailed hospital data from HospitalStats.org for all 50 US states and their counties.
#
# ## Features
# - **State & County Discovery**: Automatically discovers all 50 US states and their ~3000+ counties
# - **Hospital Listings**: Extracts hospital names, cities, and ER wait times from county pages
# - **Detailed Metrics**: Scrapes comprehensive data from each hospital's detail page:
#   - Basic Information: Address, phone, hospital type, emergency services
#   - Mortality Rates: Overall, heart attack, stroke, heart failure, pneumonia
#   - Infection Data: C. Diff and MRSA case counts
#   - ER Wait Times: Average time spent in emergency department
#   - Patient Ratings: Overall rating, positive/negative feedback
#
# ## Usage
# 1. Run all cells sequentially
# 2. Adjust `MAX_COUNTIES` in the configuration cell to control scope
# 3. Set `ENRICH_DATA = True` to scrape detail pages (slower but more data)
# 4. Results will be saved to `out/us_states_TIMESTAMP/`

# %%
# Import required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import time
import datetime as dt
from pathlib import Path
from typing import Optional, List, Dict
from urllib.parse import urljoin

print("✓ All libraries imported successfully")
# Out:
# ✓ All libraries imported successfully

# %% [markdown]
# ## Configuration
#
# Adjust these settings to control the scraping behavior:

# %%
# Configuration Settings
BASE_URL = "https://www.hospitalstats.org"
DELAY = 0.8  # Delay between requests in seconds (be polite!)

# Scraping scope
MAX_COUNTIES = None  # Set to None to scrape all counties, or a number to limit (e.g., 5 for testing)
ENRICH_DATA = True  # Set to False to skip detail page scraping (faster but less data)

# Output directory
OUTPUT_DIR = Path("out")

print(f"Configuration:")
print(f"  - Base URL: {BASE_URL}")
print(f"  - Delay: {DELAY}s between requests")
print(f"  - Max counties: {MAX_COUNTIES if MAX_COUNTIES else 'ALL (~3000)'}")
print(f"  - Enrich with detail pages: {ENRICH_DATA}")
print(f"  - Output directory: {OUTPUT_DIR}")
# Out:
# Configuration:
#   - Base URL: https://www.hospitalstats.org
#   - Delay: 0.8s between requests
#   - Max counties: ALL (~3000)
#   - Enrich with detail pages: True
#   - Output directory: out

# %% [markdown]
# ## Helper Functions
#
# These functions handle HTTP requests and HTML parsing:

# %%
def fetch_html(url: str, delay: float = DELAY) -> Optional[str]:
    """
    Fetch HTML content from a URL with error handling.
    
    Args:
        url: URL to fetch
        delay: Delay before request (seconds)
    
    Returns:
        HTML content as string, or None if error
    """
    time.sleep(delay)
    try:
        resp = requests.get(url, timeout=30)
        resp.raise_for_status()
        return resp.text
    except Exception as e:
        print(f"ERROR fetching {url}: {e}")
        return None

def parse_wait_time(text: str) -> Optional[int]:
    """
    Parse wait time text like '2h 15m' into minutes.
    
    Args:
        text: Wait time text (e.g., "2h 15m", "45m", "1h")
    
    Returns:
        Total minutes as integer, or None if parsing fails
    """
    if not text or text.strip() == "":
        return None
    
    total_minutes = 0
    
    # Match hours (e.g., "2h")
    h_match = re.search(r'(\d+)\s*h', text, re.IGNORECASE)
    if h_match:
        total_minutes += int(h_match.group(1)) * 60
    
    # Match minutes (e.g., "15m")
    m_match = re.search(r'(\d+)\s*m', text, re.IGNORECASE)
    if m_match:
        total_minutes += int(m_match.group(1))
    
    return total_minutes if total_minutes > 0 else None

print("✓ Helper functions defined")
# Out:
# ✓ Helper functions defined

# %% [markdown]
# ## Detail Page Parsing
#
# This function extracts comprehensive data from individual hospital detail pages:

# %%
def parse_detail_page(html: str, url: str) -> dict:
    """
    Extract comprehensive metrics from a hospital's detail page:
    - Address, phone, hospital type, emergency services
    - Mortality rates (overall, heart attack, stroke, heart failure, pneumonia)
    - Infection cases (C. Diff, MRSA)
    - Average ER wait time
    - Patient ratings (overall, positive points, negative points)
    """
    from bs4 import NavigableString, Tag
    
    def clean(s):
        """Strip and normalize whitespace"""
        return re.sub(r'\s+', ' ', (s or "").strip())
    
    def to_percent(s):
        """Extract percentage from string"""
        if not s:
            return None
        m = re.search(r'(\d+(?:\.\d+)?)\s*%', str(s))
        return float(m.group(1)) if m else None
    
    def node_text(n) -> str:
        """Return visible text for any BeautifulSoup node"""
        if n is None:
            return ""
        if isinstance(n, NavigableString):
            return str(n)
        if hasattr(n, "get_text"):
            return n.get_text(" ", strip=True)
        return str(n)
    
    def safe_join(parts, sep=" "):
        """Join any list/iterable of nodes/strings safely as text"""
        return sep.join([node_text(p) for p in parts if p is not None and node_text(p)])
    
    def text_after_b(soup, label_regex):
        """Find <b>Label:</b> VALUE in the same parent"""
        for b in soup.find_all("b"):
            if re.search(label_regex, b.get_text(" ", strip=True), re.I):
                parts = []
                for sib in b.next_siblings:
                    if isinstance(sib, Tag) and sib.name == "br":
                        break
                    parts.append(sib)
                txt = clean(safe_join(parts))
                if txt:
                    return txt
        return None
    
    soup = BeautifulSoup(html, "html.parser")
    h1 = soup.find(["h1", "h2"])
    name = clean(h1.get_text(" ", strip=True)) if h1 else None

    # Address/phone block
    address = city = state = postal = phone = None
    left = soup.select('div[style*="float:left"][style*="width:40%"]')
    if left:
        addr_html = left[0]
        lines = [x for x in addr_html.get_text("\n", strip=True).split("\n") if x]
        if lines:
            address = clean(lines[0])
        if len(lines) >= 2:
            m = re.search(r"(.+?),\s*([A-Z]{2})\s+(\d{5}(?:-\d{4})?)", lines[1])
            if m:
                city, state, postal = clean(m.group(1)), m.group(2), m.group(3)
        b_phone = addr_html.find("b", string=re.compile(r"^\s*Phone\s*:\s*$", re.I))
        if b_phone:
            parts = []
            for sib in b_phone.next_siblings:
                if isinstance(sib, Tag) and sib.name == "br":
                    break
                parts.append(sib)
            maybe_phone = safe_join(parts)
            pm = re.search(r"\(?\d{3}\)?[ -]?\d{3}[ -]?\d{4}", maybe_phone)
            if pm:
                phone = pm.group(0)

    hosp_type = text_after_b(soup, r"Hospital\s*Type")
    emergency_services = text_after_b(soup, r"Emergency\s*Services")
    if emergency_services:
        es = emergency_services.upper()
        emergency_services = "YES" if "YES" in es else ("NO" if "NO" in es else emergency_services)

    # Quality section - Mortality rates
    quality_hdr = soup.find(id="Quality")
    mort_text = mort_pct = mort_dir = None
    ha = st = hf = pn = None
    if quality_hdr:
        span = quality_hdr.find_next("span", class_="bigstat")
        if span:
            mort_text = clean(span.get_text(" ", strip=True))
            m = re.search(r"(\d+(?:\.\d+)?)\s*%", mort_text)
            mort_pct = float(m.group(1)) if m else None
            d = re.search(r"\b(better|worse)\b", mort_text, re.I)
            mort_dir = d.group(1).lower() if d else None
        tbl = quality_hdr.find_next("table")
        if tbl:
            for tr in tbl.find_all("tr"):
                th = tr.find("th")
                tds = tr.find_all("td")
                if not th or not tds:
                    continue
                label = clean(th.get_text(" ", strip=True))
                pct = to_percent(tds[0].get_text(" ", strip=True))
                if re.search(r"Heart Attack", label, re.I):
                    ha = pct
                elif re.search(r"Stroke", label, re.I):
                    st = pct
                elif re.search(r"Heart Failure", label, re.I):
                    hf = pct
                elif re.search(r"Pneumonia", label, re.I):
                    pn = pct

    # Infections
    c_diff = mrsa = None
    inf = soup.find(id="infectious")
    if inf:
        tbl = inf.find_next("table")
        if tbl:
            for tr in tbl.find_all("tr"):
                tds = tr.find_all("td")
                if len(tds) != 2:
                    continue
                label = tds[0].get_text(" ", strip=True)
                val = re.sub(r"[^\d]", "", tds[1].get_text(" ", strip=True)) or None
                val = int(val) if val else None
                if re.search(r"C\.\s*Diff", label, re.I):
                    c_diff = val
                if re.search(r"MRSA", label, re.I):
                    mrsa = val

    # ER wait time
    avg_ed_min = None
    er = soup.find(id="erwait")
    if er:
        span = (er.find_parent() or er).find("span", "bigstat")
        if span:
            avg_ed_min = parse_wait_time(span.get_text(" ", strip=True))

    # Patient ratings
    overall_patient_rating = None
    positive_points = negative_points = None

    pr_hdr = soup.find(id="patientratings")
    if pr_hdr:
        # Overall rating
        span = pr_hdr.find_next("span", class_="bigstat")
        if span:
            overall_patient_rating = clean(span.get_text(" ", strip=True))

        # Positive box
        pos_h3 = soup.find("h3", string=re.compile(r"Positive\s+Patient\s+Ratings", re.I))
        if pos_h3:
            pos_box = pos_h3.find_parent("div")
            if pos_box:
                ul = pos_box.find("ul")
                if ul and ul.find_all("li"):
                    positive_points = "; ".join(
                        clean(li.get_text(" ", strip=True)) for li in ul.find_all("li")
                    )
                else:
                    raw = clean(pos_box.get_text(" ", strip=True))
                    raw = re.sub(r"^\s*Positive\s+Patient\s+Ratings\s*", "", raw, flags=re.I).strip()
                    if re.search(r"No\s+consistently\s+positive\s+ratings", raw, re.I):
                        positive_points = None
                    elif raw:
                        positive_points = raw

        # Negative box
        neg_h3 = soup.find("h3", string=re.compile(r"Negative\s+Patient\s+Ratings", re.I))
        if neg_h3:
            neg_box = neg_h3.find_parent("div")
            if neg_box:
                ul = neg_box.find("ul")
                if ul and ul.find_all("li"):
                    negative_points = "; ".join(
                        clean(li.get_text(" ", strip=True)) for li in ul.find_all("li")
                    )

        # Safety: if positive == negative (selector leak), blank out positive
        if positive_points and negative_points and positive_points == negative_points:
            positive_points = None

    return {
        "detail_url": url,
        "detail_name": name,
        "detail_address": address,
        "detail_city": city,
        "detail_state": state,
        "detail_zip": postal,
        "detail_phone": phone,
        "detail_hospital_type": hosp_type,
        "detail_emergency_services": emergency_services,
        "detail_mortality_overall_text": mort_text,
        "detail_mortality_overall_percent": mort_pct,
        "detail_mortality_overall_direction": mort_dir,
        "detail_mortality_heart_attack_percent": ha,
        "detail_mortality_stroke_percent": st,
        "detail_mortality_heart_failure_percent": hf,
        "detail_mortality_pneumonia_percent": pn,
        "detail_c_diff_cases": c_diff,
        "detail_mrsa_cases": mrsa,
        "detail_avg_time_in_ed_minutes": avg_ed_min,
        "detail_overall_patient_rating": overall_patient_rating,
        "detail_positive_patient_ratings": positive_points,
        "detail_negative_patient_ratings": negative_points,
    }

print("✓ Detail page parser defined")
# Out:
# ✓ Detail page parser defined

# %% [markdown]
# ## State and County Discovery
#
# These functions discover all US states and their counties:

# %%
# All 50 US state abbreviations
US_ABBR = {
    "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA",
    "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD",
    "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ",
    "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC",
    "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"
}

def get_united_state_links() -> pd.DataFrame:
    """Discover all 50 US states and their county list pages."""
    base_url = f"{BASE_URL}/ER-Wait-Time/"
    html = fetch_html(base_url, delay=0)
    if not html:
        return pd.DataFrame(columns=["state_abbr", "state_url"])
    
    soup = BeautifulSoup(html, "html.parser")
    
    # Find the section with the state list
    container = None
    for h3 in soup.find_all("h3"):
        if "Browse Emergency Room Stats by State" in h3.get_text(strip=True):
            container = h3.parent
            break
    anchors = container.find_all("a", href=True) if container else soup.find_all("a", href=True)

    rows = []
    for a in anchors:
        href = a["href"]
        # Looks like "IL-Counties.htm"
        if re.fullmatch(r"[A-Z]{2}-Counties\.htm", href):
            abbr = a.get_text(strip=True).upper() or href.split("-")[0]
            if abbr in US_ABBR:
                rows.append({
                    "state_abbr": abbr,
                    "state_url": urljoin(base_url, href)
                })
    return pd.DataFrame(rows).drop_duplicates().sort_values("state_abbr").reset_index(drop=True)


def discover_counties_for_state(state_abbr: str, state_url: str) -> pd.DataFrame:
    """
    For a given state page, return county name + absolute URL.
    Targets anchors like: <a href="Ada-County-ID.htm">Ada</a>
    """
    html = fetch_html(state_url)
    if not html:
        return pd.DataFrame(columns=["state_abbr", "county_name", "county_url"])
    
    soup = BeautifulSoup(html, "html.parser")
    content = soup.find(id="content") or soup
    
    rows = []
    for a in content.find_all("a", href=True):
        href = a["href"]
        # Pattern: "Ada-County-ID.htm"
        if re.search(r"-County-[A-Z]{2}\.htm$", href, re.I):
            county_name = a.get_text(strip=True)
            if county_name:
                # Build absolute URL with /ER-Wait-Time/ prefix
                county_url = urljoin(f"{BASE_URL}/ER-Wait-Time/", href)
                rows.append({
                    "state_abbr": state_abbr,
                    "county_name": county_name,
                    "county_url": county_url
                })
    
    return pd.DataFrame(rows).drop_duplicates().reset_index(drop=True)


def build_united_counties_df() -> pd.DataFrame:
    """Discover all US states and their counties."""
    print("Discovering US states...")
    df_states = get_united_state_links()
    print(f"Found {len(df_states)} states\n")
    
    all_parts = []
    for idx, row in df_states.iterrows():
        abbr = row["state_abbr"]
        state_url = row["state_url"]
        print(f"[{idx+1}/{len(df_states)}] Discovering counties in {abbr}...")
        df_counties = discover_counties_for_state(abbr, state_url)
        print(f"  → Found {len(df_counties)} counties")
        all_parts.append(df_counties)
    
    df_counties = pd.concat(all_parts, ignore_index=True) if all_parts else pd.DataFrame(
        columns=["state_abbr", "county_name", "county_url"]
    )
    
    print(f"\n✓ Total counties discovered: {len(df_counties)}")
    return df_counties

print("✓ State and county discovery functions defined")
# Out:
# ✓ State and county discovery functions defined

# %% [markdown]
# ## County Page Parsing
#
# This function extracts hospital listings from county pages:

# %%
def parse_county_page(county_url: str) -> pd.DataFrame:
    """
    Parse a county page and extract hospital data.
    Returns DataFrame with columns: hospital_name, city, wait_text, wait_minutes, detail_url, source_url
    """
    html = fetch_html(county_url)
    if not html:
        return pd.DataFrame()
    
    soup = BeautifulSoup(html, "html.parser")
    content = soup.find(id="content") or soup
    
    rows = []
    for tr in content.find_all("tr"):
        tds = tr.find_all("td")
        if len(tds) < 3:
            continue
        
        # Column 0: Hospital name (with link to detail page)
        a = tds[0].find("a", href=True)
        if not a:
            continue
        hospital_name = a.get_text(strip=True)
        detail_href = a["href"]
        detail_url = urljoin(BASE_URL, detail_href)
        
        # Column 1: City
        city = tds[1].get_text(strip=True)
        
        # Column 2: Wait time
        wait_text = tds[2].get_text(strip=True)
        wait_minutes = parse_wait_time(wait_text)
        
        rows.append({
            "hospital_name": hospital_name,
            "city": city,
            "wait_text": wait_text,
            "wait_minutes": wait_minutes,
            "detail_url": detail_url,
            "source_url": county_url
        })
    
    return pd.DataFrame(rows)

print("✓ County page parser defined")
# Out:
# ✓ County page parser defined

# %% [markdown]
# ## Data Enrichment
#
# This function enriches hospital data by visiting detail pages:

# %%
def enrich_df_inline(df: pd.DataFrame, delay: float = DELAY) -> pd.DataFrame:
    """
    Enrich a DataFrame by visiting each hospital's detail page.
    Adds detailed metrics columns to the DataFrame.
    """
    if df.empty or "detail_url" not in df.columns:
        return df
    
    detail_cols = [
        "detail_name", "detail_address", "detail_city", "detail_state", "detail_zip",
        "detail_phone", "detail_hospital_type", "detail_emergency_services",
        "detail_mortality_overall_text", "detail_mortality_overall_percent",
        "detail_mortality_overall_direction", "detail_mortality_heart_attack_percent",
        "detail_mortality_stroke_percent", "detail_mortality_heart_failure_percent",
        "detail_mortality_pneumonia_percent", "detail_c_diff_cases", "detail_mrsa_cases",
        "detail_avg_time_in_ed_minutes", "detail_overall_patient_rating",
        "detail_positive_patient_ratings", "detail_negative_patient_ratings"
    ]
    
    # Initialize columns
    for col in detail_cols:
        df[col] = None
    
    print(f"  Enriching {len(df)} hospitals with detail page data...")
    
    for idx, row in df.iterrows():
        detail_url = row["detail_url"]
        if pd.isna(detail_url):
            continue
        
        html = fetch_html(detail_url, delay=delay)
        if not html:
            continue
        
        try:
            detail_data = parse_detail_page(html, detail_url)
            for col in detail_cols:
                if col in detail_data:
                    df.at[idx, col] = detail_data[col]
        except Exception as e:
            print(f"    ERROR parsing detail page {detail_url}: {e}")
    
    # Add scrape timestamp
    df["scrape_ts"] = dt.datetime.now(dt.timezone.utc).isoformat()
    
    return df

print("✓ Data enrichment function defined")
# Out:
# ✓ Data enrichment function defined

# %% [markdown]
# ## Main Scraping Function
#
# This function orchestrates the scraping of all counties:

# %%
def scrape_all_counties(df_counties: pd.DataFrame, max_counties: int = None, enrich: bool = True) -> pd.DataFrame:
    """
    Scrape hospital data from all county pages.
    
    Args:
        df_counties: DataFrame with county information
        max_counties: Limit to N counties (for testing), or None for all
        enrich: Whether to enrich with detail page data
    
    Returns:
        DataFrame with all hospital data
    """
    if max_counties:
        df_counties = df_counties.head(max_counties)
    
    all_hospitals = []
    total = len(df_counties)
    
    print(f"\nScraping {total} counties...")
    print("=" * 60)
    
    for idx, row in df_counties.iterrows():
        state_abbr = row["state_abbr"]
        county_name = row["county_name"]
        county_url = row["county_url"]
        
        print(f"[{idx+1}/{total}] {state_abbr} - {county_name}...", end=" ")
        
        df_hospitals = parse_county_page(county_url)
        
        if df_hospitals.empty:
            print("No hospitals found")
            continue
        
        # Add state and county info
        df_hospitals["state_abbr"] = state_abbr
        df_hospitals["county_name"] = county_name
        
        # Enrich with detail page data if requested
        if enrich:
            df_hospitals = enrich_df_inline(df_hospitals)
        
        print(f"Found {len(df_hospitals)} hospitals")
        all_hospitals.append(df_hospitals)
    
    print("=" * 60)
    
    if not all_hospitals:
        print("No hospitals found!")
        return pd.DataFrame()
    
    df_all = pd.concat(all_hospitals, ignore_index=True)
    print(f"\n✓ Total hospitals scraped: {len(df_all)}")
    
    return df_all

print("✓ Main scraping function defined")
# Out:
# ✓ Main scraping function defined

# %% [markdown]
# ## Export and Summary Functions
#
# These functions handle data export and summary statistics:

# %%
def export_results(df_hospitals: pd.DataFrame, outdir: Path) -> pd.DataFrame:
    """
    Export hospital data to CSV with specific column order.
    
    Args:
        df_hospitals: DataFrame with hospital data
        outdir: Output directory path
    
    Returns:
        DataFrame with reordered columns
    """
    # Define column order
    base_cols = [
        "state_abbr", "county_name", "hospital_name", "city",
        "wait_text", "wait_minutes", "detail_url"
    ]
    
    detail_cols = [
        "detail_name", "detail_address", "detail_city", "detail_state", "detail_zip",
        "detail_phone", "detail_hospital_type", "detail_emergency_services",
        "detail_mortality_overall_text", "detail_mortality_overall_percent",
        "detail_mortality_overall_direction", "detail_mortality_heart_attack_percent",
        "detail_mortality_stroke_percent", "detail_mortality_heart_failure_percent",
        "detail_mortality_pneumonia_percent", "detail_c_diff_cases", "detail_mrsa_cases",
        "detail_avg_time_in_ed_minutes", "detail_overall_patient_rating",
        "detail_positive_patient_ratings", "detail_negative_patient_ratings"
    ]
    
    # Reorder columns
    ordered_cols = base_cols + detail_cols + ["source_url", "scrape_ts"]
    existing_cols = [c for c in ordered_cols if c in df_hospitals.columns]
    df_hospitals = df_hospitals[existing_cols]
    
    # Export
    csv_path = outdir / "us_hospitals_data_enriched.csv"
    df_hospitals.to_csv(csv_path, index=False, encoding="utf-8")
    print(f"\n✓ Data exported to: {csv_path}")
    
    return df_hospitals


def print_summary(df_hospitals: pd.DataFrame, outdir: Path):
    """Print summary statistics about the scraped data."""
    print("\n" + "=" * 60)
    print("SUMMARY STATISTICS")
    print("=" * 60)
    
    print(f"Total hospitals: {len(df_hospitals)}")
    print(f"States covered: {df_hospitals['state_abbr'].nunique()}")
    print(f"Counties covered: {df_hospitals['county_name'].nunique()}")
    
    if "wait_minutes" in df_hospitals.columns:
        avg_wait = df_hospitals["wait_minutes"].mean()
        if not pd.isna(avg_wait):
            print(f"Average ER wait time: {avg_wait:.1f} minutes")
    
    if "detail_mortality_overall_percent" in df_hospitals.columns:
        enriched = df_hospitals["detail_mortality_overall_percent"].notna().sum()
        print(f"Hospitals with detailed metrics: {enriched}")
    
    print(f"\nOutput directory: {outdir}")
    print("=" * 60)

print("✓ Export and summary functions defined")
# Out:
# ✓ Export and summary functions defined

# %% [markdown]
# ---
#
# ## RUN THE SCRAPER
#
# Execute the cells below to run the comprehensive scraper:

# %% [markdown]
# ### Step 1: Discover Counties
#
# This will discover all US states and their counties:

# %%
# Step 1: Discover all counties
df_counties = build_united_counties_df()

# Preview the counties
print("\nFirst 10 counties:")
print(df_counties.head(10))
# Out:
# Discovering US states...
# Found 50 states
#
# [1/50] Discovering counties in AK...
#   → Found 12 counties
# [2/50] Discovering counties in AL...
#   → Found 58 counties
# [3/50] Discovering counties in AR...
#   → Found 53 counties
# [4/50] Discovering counties in AZ...
#   → Found 14 counties
# [5/50] Discovering counties in CA...
#   → Found 56 counties
# [6/50] Discovering counties in CO...
#   → Found 40 counties
# [7/50] Discovering counties in CT...
#   → Found 8 counties
# [8/50] Discovering counties in DE...
#   → Found 3 counties
# [9/50] Discovering counties in FL...
#   → Found 56 counties
# [10/50] Discovering counties in GA...
#   → Found 106 counties
# [11/50] Discovering counties in HI...
#   → Found 4 counties
# [12/50] Discovering counties in IA...
#   → Found 88 counties
# [13/50] Discovering counties in ID...
#   → Found 28 counties
# [14/50] Discovering counties in IL...
#   → Found 75 counties
# [15/50] Discovering counties in IN...
#   → Found 75 counties
# [16/50] Discovering counties in KS...
#   → Found 80 counties
# [17/50] Discovering counties in KY...
#   → Found 80 counties
# [18/50] Discovering counties in LA...
#   → Found 53 counties
# [19/50] Discovering counties in MA...
#   → Found 14 counties
# [20/50] Discovering counties in MD...
#   → Found 21 counties
# [21/50] Discovering counties in ME...
#   → Found 15 counties
# [22/50] Discovering counties in MI...
#   → Found 72 counties
# [23/50] Discovering counties in MN...
#   → Found 81 counties
# [24/50] Discovering counties in MO...
#   → Found 66 counties
# [25/50] Discovering counties in MS...
#   → Found 68 counties
# [26/50] Discovering counties in MT...
#   → Found 44 counties
# [27/50] Discovering counties in NC...
#   → Found 82 counties
# [28/50] Discovering counties in ND...
#   → Found 34 counties
# [29/50] Discovering counties in NE...
#   → Found 67 counties
# [30/50] Discovering counties in NH...
#   → Found 10 counties
# [31/50] Discovering counties in NJ...
#   → Found 21 counties
# [32/50] Discovering counties in NM...
#   → Found 24 counties
# [33/50] Discovering counties in NV...
#   → Found 14 counties
# [34/50] Discovering counties in NY...
#   → Found 57 counties
# [35/50] Discovering counties in OH...
#   → Found 78 counties
# [36/50] Discovering counties in OK...
#   → Found 72 counties
# [37/50] Discovering counties in OR...
#   → Found 32 counties
# [38/50] Discovering counties in PA...
#   → Found 60 counties
# [39/50] Discovering counties in RI...
#   → Found 4 counties
# [40/50] Discovering counties in SC...
#   → Found 39 counties
# [41/50] Discovering counties in SD...
#   → Found 33 counties
# [42/50] Discovering counties in TN...
#   → Found 76 counties
# [43/50] Discovering counties in TX...
#   → Found 165 counties
# [44/50] Discovering counties in UT...
#   → Found 23 counties
# [45/50] Discovering counties in VA...
#   → Found 65 counties
# [46/50] Discovering counties in VT...
#   → Found 12 counties
# [47/50] Discovering counties in WA...
#   → Found 35 counties
# [48/50] Discovering counties in WI...
#   → Found 64 counties
# [49/50] Discovering counties in WV...
#   → Found 41 counties
# [50/50] Discovering counties in WY...
#   → Found 22 counties
#
# ✓ Total counties discovered: 2400
#
# First 10 counties:
#   state_abbr           county_name  \
# 0         AK             Anchorage
# 1         AK                Bethel
# 2         AK            Dillingham
# 3         AK  Fairbanks North Star
# 4         AK                Juneau
# 5         AK       Kenai Peninsula
# 6         AK     Ketchikan Gateway
# 7         AK         Kodiak Island
# 8         AK     Matanuska Susitna
# 9         AK                  Nome
#
#                                           county_url
# 0  https://www.hospitalstats.org/ER-Wait-Time/Anc...
# 1  https://www.hospitalstats.org/ER-Wait-Time/Bet...
# 2  https://www.hospitalstats.org/ER-Wait-Time/Dil...
# 3  https://www.hospitalstats.org/ER-Wait-Time/Fai...
# 4  https://www.hospitalstats.org/ER-Wait-Time/Jun...
# 5  https://www.hospitalstats.org/ER-Wait-Time/Ken...
# 6  https://www.hospitalstats.org/ER-Wait-Time/Ket...
# 7  https://www.hospitalstats.org/ER-Wait-Time/Kod...
# 8  https://www.hospitalstats.org/ER-Wait-Time/Mat...
# 9  https://www.hospitalstats.org/ER-Wait-Time/Nom...

# %% [markdown]
# ### Step 2: Setup Output Directory
#
# Create a timestamped output directory:

# %%
# Step 2: Setup output directory
stamp = dt.datetime.now(dt.timezone.utc).strftime("%Y%m%d_%H%M%S")
outdir = OUTPUT_DIR / f"us_states_{stamp}"
outdir.mkdir(parents=True, exist_ok=True)

print(f"Output directory: {outdir}")

# Save counties list
counties_csv = outdir / "counties_list.csv"
df_counties.to_csv(counties_csv, index=False)
print(f"Counties list saved to: {counties_csv}")
# Out:
# Output directory: out\us_states_20251018_165814
# Counties list saved to: out\us_states_20251018_165814\counties_list.csv

# %% [markdown]
# ### Step 3: Scrape Hospital Data
#
# This will scrape hospital data from all counties (or limited by MAX_COUNTIES):
#
# **Note:** This may take a while depending on MAX_COUNTIES setting!

# %%
# Step 3: Scrape hospital data
df_hospitals = scrape_all_counties(
    df_counties,
    max_counties=MAX_COUNTIES,
    enrich=ENRICH_DATA
)

# Preview the data
print("\nFirst 5 hospitals:")
print(df_hospitals.head())
# Out:
# Scraping 2400 counties...
# ============================================================
# [1/2400] AK - Anchorage...   Enriching 5 hospitals with detail page data...
# Found 5 hospitals
# [2/2400] AK - Bethel... No hospitals found
# [3/2400] AK - Dillingham... No hospitals found
# [4/2400] AK - Fairbanks North Star...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [5/2400] AK - Juneau...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [6/2400] AK - Kenai Peninsula...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [7/2400] AK - Ketchikan Gateway...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [8/2400] AK - Kodiak Island... No hospitals found
# [9/2400] AK - Matanuska Susitna...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [10/2400] AK - Nome... No hospitals found
# [11/2400] AK - Sitka... No hospitals found
# [12/2400] AK - Valdez Cordova...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [13/2400] AL - Autauga...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [14/2400] AL - Baldwin...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [15/2400] AL - Barbour...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [16/2400] AL - Bibb...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [17/2400] AL - Blount... No hospitals found
# [18/2400] AL - Bullock...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [19/2400] AL - Butler...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [20/2400] AL - Calhoun...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [21/2400] AL - Chambers...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [22/2400] AL - Cherokee...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [23/2400] AL - Chilton...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [24/2400] AL - Clarke...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [25/2400] AL - Clay...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [26/2400] AL - Coffee...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [27/2400] AL - Colbert...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [28/2400] AL - Conecuh...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [29/2400] AL - Covington...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [30/2400] AL - Crenshaw...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [31/2400] AL - Cullman...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [32/2400] AL - Dale...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [33/2400] AL - Dallas...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [34/2400] AL - De Kalb...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [35/2400] AL - Elmore...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [36/2400] AL - Escambia...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [37/2400] AL - Etowah...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [38/2400] AL - Fayette...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [39/2400] AL - Franklin...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [40/2400] AL - Geneva...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [41/2400] AL - Greene...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [42/2400] AL - Hale...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [43/2400] AL - Houston...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [44/2400] AL - Jackson...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [45/2400] AL - Jefferson...   Enriching 10 hospitals with detail page data...
# Found 10 hospitals
# [46/2400] AL - Lauderdale...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [47/2400] AL - Lawrence...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [48/2400] AL - Lee...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [49/2400] AL - Limestone...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [50/2400] AL - Madison...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [51/2400] AL - Marengo...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [52/2400] AL - Marion...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [53/2400] AL - Marshall...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [54/2400] AL - Mobile...   Enriching 6 hospitals with detail page data...
# Found 6 hospitals
# [55/2400] AL - Monroe...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [56/2400] AL - Montgomery...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [57/2400] AL - Morgan...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [58/2400] AL - Pickens... No hospitals found
# [59/2400] AL - Pike...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [60/2400] AL - Randolph...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [61/2400] AL - Russell...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [62/2400] AL - Saint Clair... No hospitals found
# [63/2400] AL - Shelby...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [64/2400] AL - Sumter...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [65/2400] AL - Talladega...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [66/2400] AL - Tallapoosa...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [67/2400] AL - Tuscaloosa...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [68/2400] AL - Walker...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [69/2400] AL - Washington... No hospitals found
# [70/2400] AL - Winston...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [71/2400] AR - Arkansas...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [72/2400] AR - Ashley...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [73/2400] AR - Baxter...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [74/2400] AR - Benton...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [75/2400] AR - Boone...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [76/2400] AR - Bradley... No hospitals found
# [77/2400] AR - Carroll...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [78/2400] AR - Chicot...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [79/2400] AR - Clark...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [80/2400] AR - Clay...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [81/2400] AR - Cleburne...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [82/2400] AR - Columbia...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [83/2400] AR - Conway...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [84/2400] AR - Craighead...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [85/2400] AR - Crawford...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [86/2400] AR - Crittenden...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [87/2400] AR - Cross...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [88/2400] AR - Dallas...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [89/2400] AR - Desha...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [90/2400] AR - Drew...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [91/2400] AR - Faulkner...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [92/2400] AR - Franklin...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [93/2400] AR - Fulton... No hospitals found
# [94/2400] AR - Garland...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [95/2400] AR - Greene...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [96/2400] AR - Hempstead...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [97/2400] AR - Hot Spring...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [98/2400] AR - Howard...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [99/2400] AR - Independence...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [100/2400] AR - Jackson...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [101/2400] AR - Jefferson...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [102/2400] AR - Johnson...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [103/2400] AR - Lawrence...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [104/2400] AR - Little River...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [105/2400] AR - Logan...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [106/2400] AR - Mississippi...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [107/2400] AR - Ouachita...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [108/2400] AR - Phillips...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [109/2400] AR - Polk...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [110/2400] AR - Pope...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [111/2400] AR - Pulaski...   Enriching 10 hospitals with detail page data...
# ERROR fetching https://www.hospitalstats.org/hospital-ratings/st-vincent-medical-center/north-sherwood-ar.htm: 404 Client Error: Not Found for url: https://www.hospitalstats.org/hospital-ratings/st-vincent-medical-center/north-sherwood-ar.htm
# Found 10 hospitals
# [112/2400] AR - Randolph...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [113/2400] AR - Saint Francis... No hospitals found
# [114/2400] AR - Saline...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [115/2400] AR - Scott...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [116/2400] AR - Sebastian...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [117/2400] AR - Sevier... No hospitals found
# [118/2400] AR - Stone...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [119/2400] AR - Union...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [120/2400] AR - Van Buren...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [121/2400] AR - Washington...   Enriching 5 hospitals with detail page data...
# Found 5 hospitals
# [122/2400] AR - White...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [123/2400] AR - Yell...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [124/2400] AZ - Apache...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [125/2400] AZ - Cochise...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [126/2400] AZ - Coconino...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [127/2400] AZ - Gila...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [128/2400] AZ - Graham...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [129/2400] AZ - La Paz... No hospitals found
# [130/2400] AZ - Maricopa...   Enriching 30 hospitals with detail page data...
# Found 30 hospitals
# [131/2400] AZ - Mohave...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [132/2400] AZ - Navajo...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [133/2400] AZ - Pima...   Enriching 12 hospitals with detail page data...
# Found 12 hospitals
# [134/2400] AZ - Pinal...   Enriching 5 hospitals with detail page data...
# Found 5 hospitals
# [135/2400] AZ - Santa Cruz...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [136/2400] AZ - Yavapai...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [137/2400] AZ - Yuma...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [138/2400] CA - Alameda...   Enriching 11 hospitals with detail page data...
# ERROR fetching https://www.hospitalstats.org/hospital-ratings/kaiser-foundation-hospital--oakland/richmond-oakland-ca.htm: 404 Client Error: Not Found for url: https://www.hospitalstats.org/hospital-ratings/kaiser-foundation-hospital--oakland/richmond-oakland-ca.htm
# Found 11 hospitals
# [139/2400] CA - Amador...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [140/2400] CA - Butte...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [141/2400] CA - Calaveras... No hospitals found
# [142/2400] CA - Colusa...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [143/2400] CA - Contra Costa...   Enriching 8 hospitals with detail page data...
# Found 8 hospitals
# [144/2400] CA - Del Norte...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [145/2400] CA - El Dorado...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [146/2400] CA - Fresno...   Enriching 6 hospitals with detail page data...
# Found 6 hospitals
# [147/2400] CA - Glenn...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [148/2400] CA - Humboldt...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [149/2400] CA - Imperial...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [150/2400] CA - Inyo...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [151/2400] CA - Kern...   Enriching 9 hospitals with detail page data...
# Found 9 hospitals
# [152/2400] CA - Kings...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [153/2400] CA - Lake...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [154/2400] CA - Lassen...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [155/2400] CA - Los Angeles...   Enriching 53 hospitals with detail page data...
# ERROR fetching https://www.hospitalstats.org/hospital-ratings/lac/olive-view-ucla-medical-center-sylmar-ca.htm: 404 Client Error: Not Found for url: https://www.hospitalstats.org/hospital-ratings/lac/olive-view-ucla-medical-center-sylmar-ca.htm
# ERROR fetching https://www.hospitalstats.org/hospital-ratings/lac/harbor-ucla-med-center-torrance-ca.htm: 404 Client Error: Not Found for url: https://www.hospitalstats.org/hospital-ratings/lac/harbor-ucla-med-center-torrance-ca.htm
# Found 53 hospitals
# [156/2400] CA - Madera... No hospitals found
# [157/2400] CA - Marin...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [158/2400] CA - Mariposa...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [159/2400] CA - Mendocino...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [160/2400] CA - Merced...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [161/2400] CA - Modoc... No hospitals found
# [162/2400] CA - Mono...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [163/2400] CA - Monterey...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [164/2400] CA - Napa...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [165/2400] CA - Nevada...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [166/2400] CA - Orange...   Enriching 17 hospitals with detail page data...
# Found 17 hospitals
# [167/2400] CA - Placer...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [168/2400] CA - Plumas...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [169/2400] CA - Riverside...   Enriching 16 hospitals with detail page data...
# Found 16 hospitals
# [170/2400] CA - Sacramento...   Enriching 10 hospitals with detail page data...
# Found 10 hospitals
# [171/2400] CA - San Benito...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [172/2400] CA - San Bernardino...   Enriching 20 hospitals with detail page data...
# ERROR fetching https://www.hospitalstats.org/hospital-ratings/kaiser-foundation-hospital-fontana/ontario-fontana-ca.htm: 404 Client Error: Not Found for url: https://www.hospitalstats.org/hospital-ratings/kaiser-foundation-hospital-fontana/ontario-fontana-ca.htm
# Found 20 hospitals
# [173/2400] CA - San Diego...   Enriching 17 hospitals with detail page data...
# Found 17 hospitals
# [174/2400] CA - San Francisco...   Enriching 9 hospitals with detail page data...
# Found 9 hospitals
# [175/2400] CA - San Joaquin...   Enriching 6 hospitals with detail page data...
# Found 6 hospitals
# [176/2400] CA - San Luis Obispo...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [177/2400] CA - San Mateo...   Enriching 6 hospitals with detail page data...
# Found 6 hospitals
# [178/2400] CA - Santa Barbara...   Enriching 5 hospitals with detail page data...
# Found 5 hospitals
# [179/2400] CA - Santa Clara... ERROR fetching https://www.hospitalstats.org/ER-Wait-Time/Santa-Clara-County-CA.htm: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# No hospitals found
# [180/2400] CA - Santa Cruz...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [181/2400] CA - Shasta...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [182/2400] CA - Siskiyou...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [183/2400] CA - Solano...   Enriching 5 hospitals with detail page data...
# Found 5 hospitals
# [184/2400] CA - Sonoma...   Enriching 7 hospitals with detail page data...
# Found 7 hospitals
# [185/2400] CA - Stanislaus...   Enriching 4 hospitals with detail page data...
# ERROR fetching https://www.hospitalstats.org/hospital-ratings/memorial-medical-center-modesto-ca.htm: HTTPSConnectionPool(host='www.hospitalstats.org', port=443): Max retries exceeded with url: /hospital-ratings/memorial-medical-center-modesto-ca.htm (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000021D01226CD0>, 'Connection to www.hospitalstats.org timed out. (connect timeout=30)'))
# Found 4 hospitals
# [186/2400] CA - Sutter... ERROR fetching https://www.hospitalstats.org/ER-Wait-Time/Sutter-County-CA.htm: HTTPSConnectionPool(host='www.hospitalstats.org', port=443): Max retries exceeded with url: /ER-Wait-Time/Sutter-County-CA.htm (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000021D0118B350>, 'Connection to www.hospitalstats.org timed out. (connect timeout=30)'))
# No hospitals found
# [187/2400] CA - Tehama... ERROR fetching https://www.hospitalstats.org/ER-Wait-Time/Tehama-County-CA.htm: HTTPSConnectionPool(host='www.hospitalstats.org', port=443): Max retries exceeded with url: /ER-Wait-Time/Tehama-County-CA.htm (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000021D0118B750>, 'Connection to www.hospitalstats.org timed out. (connect timeout=30)'))
# No hospitals found
# [188/2400] CA - Trinity...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [189/2400] CA - Tulare...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [190/2400] CA - Tuolumne... No hospitals found
# [191/2400] CA - Ventura...   Enriching 5 hospitals with detail page data...
# Found 5 hospitals
# [192/2400] CA - Yolo...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [193/2400] CA - Yuba...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [194/2400] CO - Adams...   Enriching 5 hospitals with detail page data...
# Found 5 hospitals
# [195/2400] CO - Alamosa...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [196/2400] CO - Arapahoe...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [197/2400] CO - Archuleta...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [198/2400] CO - Baca...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [199/2400] CO - Boulder...   Enriching 5 hospitals with detail page data...
# Found 5 hospitals
# [200/2400] CO - Chaffee... No hospitals found
# [201/2400] CO - Cheyenne...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [202/2400] CO - Delta...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [203/2400] CO - Denver...   Enriching 6 hospitals with detail page data...
# ERROR fetching https://www.hospitalstats.org/hospital-ratings/presbyterian/st-lukes-medical-center-denver-co.htm: 404 Client Error: Not Found for url: https://www.hospitalstats.org/hospital-ratings/presbyterian/st-lukes-medical-center-denver-co.htm
# Found 6 hospitals
# [204/2400] CO - Douglas...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [205/2400] CO - Eagle...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [206/2400] CO - El Paso...   Enriching 7 hospitals with detail page data...
# Found 7 hospitals
# [207/2400] CO - Fremont...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [208/2400] CO - Garfield...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [209/2400] CO - Gunnison...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [210/2400] CO - Huerfano...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [211/2400] CO - Jefferson...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [212/2400] CO - Kit Carson...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [213/2400] CO - La Plata...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [214/2400] CO - Lake...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [215/2400] CO - Larimer...   Enriching 5 hospitals with detail page data...
# Found 5 hospitals
# [216/2400] CO - Las Animas...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [217/2400] CO - Logan...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [218/2400] CO - Mesa...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [219/2400] CO - Montezuma...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [220/2400] CO - Montrose...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [221/2400] CO - Morgan...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [222/2400] CO - Otero... No hospitals found
# [223/2400] CO - Phillips...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [224/2400] CO - Pitkin...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [225/2400] CO - Prowers... No hospitals found
# [226/2400] CO - Pueblo...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [227/2400] CO - Rio Blanco...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [228/2400] CO - Rio Grande... No hospitals found
# [229/2400] CO - Routt...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [230/2400] CO - Summit...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [231/2400] CO - Teller...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [232/2400] CO - Weld...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [233/2400] CO - Yuma...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [234/2400] CT - Fairfield...   Enriching 6 hospitals with detail page data...
# Found 6 hospitals
# [235/2400] CT - Hartford...   Enriching 7 hospitals with detail page data...
# Found 7 hospitals
# [236/2400] CT - Litchfield...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [237/2400] CT - Middlesex...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [238/2400] CT - New Haven...   Enriching 6 hospitals with detail page data...
# Found 6 hospitals
# [239/2400] CT - New London...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [240/2400] CT - Tolland...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [241/2400] CT - Windham...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [242/2400] DE - Kent...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [243/2400] DE - New Castle...   Enriching 5 hospitals with detail page data...
# Found 5 hospitals
# [244/2400] DE - Sussex...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [245/2400] FL - Alachua...   Enriching 3 hospitals with detail page data...
# ERROR fetching https://www.hospitalstats.org/hospital-ratings/va-north-florida/south-georgia-healthcare-system--gainesville-gainesville-fl.htm: 404 Client Error: Not Found for url: https://www.hospitalstats.org/hospital-ratings/va-north-florida/south-georgia-healthcare-system--gainesville-gainesville-fl.htm
# Found 3 hospitals
# [246/2400] FL - Bay...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [247/2400] FL - Bradford... No hospitals found
# [248/2400] FL - Brevard...   Enriching 7 hospitals with detail page data...
# Found 7 hospitals
# [249/2400] FL - Broward...   Enriching 13 hospitals with detail page data...
# Found 13 hospitals
# [250/2400] FL - Charlotte...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [251/2400] FL - Citrus...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [252/2400] FL - Clay...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [253/2400] FL - Collier...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [254/2400] FL - Columbia...   Enriching 2 hospitals with detail page data...
# ERROR fetching https://www.hospitalstats.org/hospital-ratings/va-north-florida/south-georgia-healthcare-system--lake-city-lake-city-fl.htm: 404 Client Error: Not Found for url: https://www.hospitalstats.org/hospital-ratings/va-north-florida/south-georgia-healthcare-system--lake-city-lake-city-fl.htm
# Found 2 hospitals
# [255/2400] FL - De Soto...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [256/2400] FL - Duval...   Enriching 8 hospitals with detail page data...
# Found 8 hospitals
# [257/2400] FL - Escambia...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [258/2400] FL - Flagler...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [259/2400] FL - Franklin... No hospitals found
# [260/2400] FL - Gulf...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [261/2400] FL - Hardee...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [262/2400] FL - Hendry...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [263/2400] FL - Hernando...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [264/2400] FL - Highlands...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [265/2400] FL - Hillsborough...   Enriching 9 hospitals with detail page data...
# Found 9 hospitals
# [266/2400] FL - Holmes... No hospitals found
# [267/2400] FL - Indian River...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [268/2400] FL - Jackson...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [269/2400] FL - Lake...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [270/2400] FL - Lee...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [271/2400] FL - Leon...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [272/2400] FL - Levy... No hospitals found
# [273/2400] FL - Madison...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [274/2400] FL - Manatee...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [275/2400] FL - Marion...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [276/2400] FL - Martin...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [277/2400] FL - Miami-Dade...   Enriching 19 hospitals with detail page data...
# Found 19 hospitals
# [278/2400] FL - Monroe...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [279/2400] FL - Nassau...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [280/2400] FL - Okaloosa...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [281/2400] FL - Okeechobee... No hospitals found
# [282/2400] FL - Orange...   Enriching 6 hospitals with detail page data...
# Found 6 hospitals
# [283/2400] FL - Osceola...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [284/2400] FL - Palm Beach...   Enriching 13 hospitals with detail page data...
# Found 13 hospitals
# [285/2400] FL - Pasco...   Enriching 6 hospitals with detail page data...
# Found 6 hospitals
# [286/2400] FL - Pinellas...   Enriching 12 hospitals with detail page data...
# Found 12 hospitals
# [287/2400] FL - Polk...   Enriching 5 hospitals with detail page data...
# Found 5 hospitals
# [288/2400] FL - Putnam...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [289/2400] FL - Saint Johns... No hospitals found
# [290/2400] FL - Saint Lucie... No hospitals found
# [291/2400] FL - Santa Rosa...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [292/2400] FL - Sarasota...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [293/2400] FL - Seminole...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [294/2400] FL - Sumter... No hospitals found
# [295/2400] FL - Suwannee... No hospitals found
# [296/2400] FL - Taylor...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [297/2400] FL - Union...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [298/2400] FL - Volusia...   Enriching 5 hospitals with detail page data...
# ERROR fetching https://www.hospitalstats.org/hospital-ratings/halifax-health-/uf-health-medical-center-of-delton-deltona-fl.htm: 404 Client Error: Not Found for url: https://www.hospitalstats.org/hospital-ratings/halifax-health-/uf-health-medical-center-of-delton-deltona-fl.htm
# Found 5 hospitals
# [299/2400] FL - Walton...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [300/2400] FL - Washington... No hospitals found
# [301/2400] GA - Appling...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [302/2400] GA - Bacon...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [303/2400] GA - Baldwin...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [304/2400] GA - Barrow...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [305/2400] GA - Bartow...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [306/2400] GA - Ben Hill...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [307/2400] GA - Berrien...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [308/2400] GA - Bibb...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [309/2400] GA - Bleckley...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [310/2400] GA - Brooks...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [311/2400] GA - Bulloch...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [312/2400] GA - Burke...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [313/2400] GA - Butts... No hospitals found
# [314/2400] GA - Camden...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [315/2400] GA - Candler...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [316/2400] GA - Carroll...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [317/2400] GA - Catoosa...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [318/2400] GA - Charlton... No hospitals found
# [319/2400] GA - Chatham...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [320/2400] GA - Chattooga... No hospitals found
# [321/2400] GA - Cherokee...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [322/2400] GA - Clarke...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [323/2400] GA - Clayton...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [324/2400] GA - Clinch...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [325/2400] GA - Cobb...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [326/2400] GA - Coffee...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [327/2400] GA - Colquitt...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [328/2400] GA - Cook... No hospitals found
# [329/2400] GA - Coweta...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [330/2400] GA - Crisp...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [331/2400] GA - Decatur...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [332/2400] GA - Dekalb... No hospitals found
# [333/2400] GA - Dodge...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [334/2400] GA - Dougherty...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [335/2400] GA - Douglas...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [336/2400] GA - Early...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [337/2400] GA - Effingham...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [338/2400] GA - Elbert... No hospitals found
# [339/2400] GA - Emanuel...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [340/2400] GA - Evans...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [341/2400] GA - Fannin...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [342/2400] GA - Floyd...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [343/2400] GA - Forsyth...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [344/2400] GA - Franklin...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [345/2400] GA - Fulton...   Enriching 6 hospitals with detail page data...
# Found 6 hospitals
# [346/2400] GA - Gilmer... No hospitals found
# [347/2400] GA - Glynn...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [348/2400] GA - Gordon... No hospitals found
# [349/2400] GA - Grady...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [350/2400] GA - Greene...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [351/2400] GA - Gwinnett...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [352/2400] GA - Habersham...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [353/2400] GA - Hall...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [354/2400] GA - Haralson...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [355/2400] GA - Henry...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [356/2400] GA - Houston...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [357/2400] GA - Irwin... No hospitals found
# [358/2400] GA - Jackson... No hospitals found
# [359/2400] GA - Jasper...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [360/2400] GA - Jeff Davis...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [361/2400] GA - Jefferson...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [362/2400] GA - Lanier...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [363/2400] GA - Laurens...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [364/2400] GA - Liberty...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [365/2400] GA - Lowndes...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [366/2400] GA - Lumpkin...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [367/2400] GA - Macon... No hospitals found
# [368/2400] GA - Mcduffie... No hospitals found
# [369/2400] GA - Meriwether...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [370/2400] GA - Miller...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [371/2400] GA - Mitchell...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [372/2400] GA - Monroe...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [373/2400] GA - Morgan...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [374/2400] GA - Murray...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [375/2400] GA - Muscogee...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [376/2400] GA - Newton...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [377/2400] GA - Paulding...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [378/2400] GA - Peach...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [379/2400] GA - Pickens...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [380/2400] GA - Polk...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [381/2400] GA - Pulaski...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [382/2400] GA - Putnam...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [383/2400] GA - Rabun...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [384/2400] GA - Randolph... No hospitals found
# [385/2400] GA - Richmond...   Enriching 5 hospitals with detail page data...
# Found 5 hospitals
# [386/2400] GA - Rockdale... No hospitals found
# [387/2400] GA - Seminole...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [388/2400] GA - Spalding...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [389/2400] GA - Stephens...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [390/2400] GA - Stewart... No hospitals found
# [391/2400] GA - Sumter...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [392/2400] GA - Thomas...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [393/2400] GA - Tift...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [394/2400] GA - Toombs...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [395/2400] GA - Towns...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [396/2400] GA - Troup...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [397/2400] GA - Union...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [398/2400] GA - Upson...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [399/2400] GA - Walton...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [400/2400] GA - Ware...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [401/2400] GA - Washington...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [402/2400] GA - Wayne...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [403/2400] GA - Wheeler... No hospitals found
# [404/2400] GA - Whitfield... No hospitals found
# [405/2400] GA - Wilkes...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [406/2400] GA - Worth...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [407/2400] HI - Hawaii...   Enriching 6 hospitals with detail page data...
# Found 6 hospitals
# [408/2400] HI - Honolulu...   Enriching 10 hospitals with detail page data...
# Found 10 hospitals
# [409/2400] HI - Kauai...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [410/2400] HI - Maui...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [411/2400] IA - Adair...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [412/2400] IA - Adams...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [413/2400] IA - Allamakee... No hospitals found
# [414/2400] IA - Appanoose...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [415/2400] IA - Audubon...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [416/2400] IA - Black Hawk...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [417/2400] IA - Boone...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [418/2400] IA - Bremer...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [419/2400] IA - Buchanan...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [420/2400] IA - Buena Vista...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [421/2400] IA - Calhoun...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [422/2400] IA - Carroll...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [423/2400] IA - Cass...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [424/2400] IA - Cerro Gordo...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [425/2400] IA - Cherokee...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [426/2400] IA - Chickasaw...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [427/2400] IA - Clarke...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [428/2400] IA - Clay...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [429/2400] IA - Clayton...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [430/2400] IA - Clinton...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [431/2400] IA - Crawford... No hospitals found
# [432/2400] IA - Dallas...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [433/2400] IA - Davis...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [434/2400] IA - Decatur...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [435/2400] IA - Delaware...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [436/2400] IA - Des Moines...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [437/2400] IA - Dickinson...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [438/2400] IA - Dubuque...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [439/2400] IA - Emmet...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [440/2400] IA - Fayette...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [441/2400] IA - Floyd...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [442/2400] IA - Franklin...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [443/2400] IA - Fremont...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [444/2400] IA - Greene...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [445/2400] IA - Grundy...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [446/2400] IA - Guthrie...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [447/2400] IA - Hamilton...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [448/2400] IA - Hancock...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [449/2400] IA - Hardin...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [450/2400] IA - Harrison...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [451/2400] IA - Henry... No hospitals found
# [452/2400] IA - Howard...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [453/2400] IA - Ida...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [454/2400] IA - Iowa...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [455/2400] IA - Jackson...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [456/2400] IA - Jasper...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [457/2400] IA - Jefferson...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [458/2400] IA - Johnson...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [459/2400] IA - Jones...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [460/2400] IA - Keokuk... No hospitals found
# [461/2400] IA - Kossuth...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [462/2400] IA - Lee... No hospitals found
# [463/2400] IA - Linn...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [464/2400] IA - Lucas...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [465/2400] IA - Lyon...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [466/2400] IA - Madison...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [467/2400] IA - Mahaska...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [468/2400] IA - Marion...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [469/2400] IA - Marshall...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [470/2400] IA - Mitchell...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [471/2400] IA - Monona...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [472/2400] IA - Monroe...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [473/2400] IA - Montgomery...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [474/2400] IA - Muscatine...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [475/2400] IA - Obrien...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [476/2400] IA - Osceola...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [477/2400] IA - Page...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [478/2400] IA - Palo Alto...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [479/2400] IA - Plymouth...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [480/2400] IA - Pocahontas... No hospitals found
# [481/2400] IA - Polk...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [482/2400] IA - Pottawattamie...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [483/2400] IA - Poweshiek...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [484/2400] IA - Ringgold...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [485/2400] IA - Sac... No hospitals found
# [486/2400] IA - Scott...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [487/2400] IA - Shelby...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [488/2400] IA - Sioux...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [489/2400] IA - Story...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [490/2400] IA - Union...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [491/2400] IA - Van Buren...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [492/2400] IA - Wapello...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [493/2400] IA - Washington... No hospitals found
# [494/2400] IA - Wayne... No hospitals found
# [495/2400] IA - Webster...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [496/2400] IA - Winneshiek...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [497/2400] IA - Woodbury...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [498/2400] IA - Wright...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [499/2400] ID - Ada...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [500/2400] ID - Bannock...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [501/2400] ID - Bear Lake...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# ...
# Found 1 hospitals
# [2271/2400] WA - Whatcom...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2272/2400] WA - Whitman...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2273/2400] WA - Yakima...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [2274/2400] WI - Adams...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2275/2400] WI - Ashland...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2276/2400] WI - Barron...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [2277/2400] WI - Brown...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [2278/2400] WI - Burnett... No hospitals found
# [2279/2400] WI - Calumet...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2280/2400] WI - Chippewa...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [2281/2400] WI - Clark...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2282/2400] WI - Columbia...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2283/2400] WI - Crawford...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2284/2400] WI - Dane...   Enriching 5 hospitals with detail page data...
# Found 5 hospitals
# [2285/2400] WI - Dodge...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2286/2400] WI - Door...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2287/2400] WI - Douglas...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2288/2400] WI - Dunn...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2289/2400] WI - Eau Claire...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [2290/2400] WI - Fond Du Lac...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [2291/2400] WI - Grant...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [2292/2400] WI - Green...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2293/2400] WI - Green Lake...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2294/2400] WI - Iowa...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2295/2400] WI - Jackson...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2296/2400] WI - Jefferson...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2297/2400] WI - Juneau...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2298/2400] WI - Kenosha...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2299/2400] WI - La Crosse...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2300/2400] WI - Lafayette...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2301/2400] WI - Langlade...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2302/2400] WI - Lincoln...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2303/2400] WI - Manitowoc...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2304/2400] WI - Marathon...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2305/2400] WI - Marinette...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2306/2400] WI - Milwaukee...   Enriching 10 hospitals with detail page data...
# Found 10 hospitals
# [2307/2400] WI - Monroe...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2308/2400] WI - Oconto...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2309/2400] WI - Oneida...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2310/2400] WI - Outagamie...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2311/2400] WI - Ozaukee...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2312/2400] WI - Pepin...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2313/2400] WI - Pierce...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2314/2400] WI - Polk...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [2315/2400] WI - Portage...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2316/2400] WI - Price...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2317/2400] WI - Racine...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2318/2400] WI - Richland...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2319/2400] WI - Rock...   Enriching 4 hospitals with detail page data...
# Found 4 hospitals
# [2320/2400] WI - Rusk...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2321/2400] WI - Saint Croix... No hospitals found
# [2322/2400] WI - Sauk...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [2323/2400] WI - Sawyer...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2324/2400] WI - Shawano...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2325/2400] WI - Sheboygan...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2326/2400] WI - Taylor...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2327/2400] WI - Trempealeau...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2328/2400] WI - Vernon...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2329/2400] WI - Vilas...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2330/2400] WI - Walworth...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2331/2400] WI - Washburn...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2332/2400] WI - Washington...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2333/2400] WI - Waukesha...   Enriching 6 hospitals with detail page data...
# Found 6 hospitals
# [2334/2400] WI - Waupaca...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2335/2400] WI - Waushara...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2336/2400] WI - Winnebago...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [2337/2400] WI - Wood...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2338/2400] WV - Barbour...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2339/2400] WV - Berkeley...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2340/2400] WV - Boone...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2341/2400] WV - Braxton... No hospitals found
# [2342/2400] WV - Cabell...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2343/2400] WV - Calhoun...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2344/2400] WV - Fayette...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2345/2400] WV - Grant...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2346/2400] WV - Greenbrier...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2347/2400] WV - Hampshire...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2348/2400] WV - Hancock...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2349/2400] WV - Harrison...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [2350/2400] WV - Jackson...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2351/2400] WV - Jefferson...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2352/2400] WV - Kanawha...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [2353/2400] WV - Lewis...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2354/2400] WV - Logan...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2355/2400] WV - Marion...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2356/2400] WV - Marshall...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2357/2400] WV - Mason...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2358/2400] WV - Mcdowell... No hospitals found
# [2359/2400] WV - Mercer...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2360/2400] WV - Mineral...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2361/2400] WV - Mingo... No hospitals found
# [2362/2400] WV - Monongalia...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2363/2400] WV - Morgan...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2364/2400] WV - Nicholas... No hospitals found
# [2365/2400] WV - Ohio...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2366/2400] WV - Pocahontas...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2367/2400] WV - Preston...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2368/2400] WV - Putnam... No hospitals found
# [2369/2400] WV - Raleigh...   Enriching 3 hospitals with detail page data...
# Found 3 hospitals
# [2370/2400] WV - Randolph...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2371/2400] WV - Roane... No hospitals found
# [2372/2400] WV - Summers...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2373/2400] WV - Taylor...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2374/2400] WV - Tyler...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2375/2400] WV - Upshur...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2376/2400] WV - Webster...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2377/2400] WV - Wetzel...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2378/2400] WV - Wood...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2379/2400] WY - Albany...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2380/2400] WY - Big Horn...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2381/2400] WY - Campbell...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2382/2400] WY - Carbon...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2383/2400] WY - Converse... No hospitals found
# [2384/2400] WY - Crook... No hospitals found
# [2385/2400] WY - Fremont...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2386/2400] WY - Goshen...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2387/2400] WY - Hot Springs...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2388/2400] WY - Johnson... No hospitals found
# [2389/2400] WY - Laramie...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2390/2400] WY - Lincoln...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2391/2400] WY - Natrona...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2392/2400] WY - Niobrara... No hospitals found
# [2393/2400] WY - Park...   Enriching 2 hospitals with detail page data...
# Found 2 hospitals
# [2394/2400] WY - Platte...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2395/2400] WY - Sheridan...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2396/2400] WY - Sweetwater...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2397/2400] WY - Teton...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2398/2400] WY - Uinta...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2399/2400] WY - Washakie...   Enriching 1 hospitals with detail page data...
# Found 1 hospitals
# [2400/2400] WY - Weston... No hospitals found
# ============================================================
#
# ✓ Total hospitals scraped: 4088
#
# First 5 hospitals:
#                                        hospital_name       city wait_text  \
# 0  673rd Medical Group (Joint Base Elmendorf-Rich...       Jber    1h 53m
# 1                       Alaska Native Medical Center  Anchorage    2h 13m
# 2                           Alaska Regional Hospital  Anchorage    2h 33m
# 3                   Providence Alaska Medical Center  Anchorage    3h 12m
# 4                                North Star Hospital  Anchorage       N/A
#
#    wait_minutes                                         detail_url  \
# 0         113.0  https://www.hospitalstats.org/hospital-ratings...
# 1         133.0  https://www.hospitalstats.org/hospital-ratings...
# 2         153.0  https://www.hospitalstats.org/hospital-ratings...
# 3         192.0  https://www.hospitalstats.org/hospital-ratings...
# 4           NaN  https://www.hospitalstats.org/hospital-ratings...
#
#                                           source_url state_abbr county_name  \
# 0  https://www.hospitalstats.org/ER-Wait-Time/Anc...         AK   Anchorage
# 1  https://www.hospitalstats.org/ER-Wait-Time/Anc...         AK   Anchorage
# 2  https://www.hospitalstats.org/ER-Wait-Time/Anc...         AK   Anchorage
# 3  https://www.hospitalstats.org/ER-Wait-Time/Anc...         AK   Anchorage
# 4  https://www.hospitalstats.org/ER-Wait-Time/Anc...         AK   Anchorage
#
#                                          detail_name           detail_address  \
# 0  673rd Medical Group (Joint Base Elmendorf-Rich...  673 Mdg 5955 Zeamer Ave
# 1               Alaska Native Medical Center Ratings        4315 Diplomacy Dr
# 2                   Alaska Regional Hospital Ratings         2801 Debarr Road
# 3           Providence Alaska Medical Center Ratings    3200 Providence Drive
# 4                        North Star Hospital Ratings           2530 Debarr Rd
#
#    ... detail_mortality_stroke_percent detail_mortality_heart_failure_percent  \
# 0  ...                            None                                   None
# 1  ...                            15.9                                   12.3
# 2  ...                            11.8                                   10.1
# 3  ...                            14.9                                   12.5
# 4  ...                            None                                   None
#
#   detail_mortality_pneumonia_percent detail_c_diff_cases detail_mrsa_cases  \
# 0                               None                   1              None
# 1                               17.4                   6                 2
# 2                               19.0                  13                 0
# 3                               17.6                  10                 5
# 4                               None                None              None
#
#   detail_avg_time_in_ed_minutes detail_overall_patient_rating  \
# 0                           113                     VERY GOOD
# 1                           133                       AVERAGE
# 2                           153                       AVERAGE
# 3                           192                       AVERAGE
# 4                          None                          POOR
#
#                      detail_positive_patient_ratings  \
# 0  Nurses usually respond quickly when patients n...
# 1     Doctors usually communicate well with patients
# 2  Nurses usually take time to communicate well; ...
# 3  Nurses usually take time to communicate well; ...
# 4                                               None
#
#                      detail_negative_patient_ratings  \
# 0                                               None
# 1  Staff doesn't respond quickly when patients ne...
# 2  Staff doesn't respond quickly when patients ne...
# 3  Staff doesn't respond quickly when patients ne...
# 4  Staff doesn't respond quickly when patients ne...
#
#                           scrape_ts
# 0  2025-10-18T16:58:32.063499+00:00
# 1  2025-10-18T16:58:32.063499+00:00
# 2  2025-10-18T16:58:32.063499+00:00
# 3  2025-10-18T16:58:32.063499+00:00
# 4  2025-10-18T16:58:32.063499+00:00
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Step 4: Export Results
#
# Export the scraped data to CSV:

# %%
# Step 4: Export results
df_hospitals = export_results(df_hospitals, outdir)
# Out:
# ✓ Data exported to: out\us_states_20251018_165814\us_hospitals_data_enriched.csv

# %% [markdown]
# ### Step 5: Print Summary
#
# Display summary statistics:

# %%
# Step 5: Print summary
print_summary(df_hospitals, outdir)
# Out:
# ============================================================
# SUMMARY STATISTICS
# ============================================================
# Total hospitals: 4088
# States covered: 50
# Counties covered: 1326
# Average ER wait time: 162.1 minutes
# Hospitals with detailed metrics: 3173
#
# Output directory: out\us_states_20251018_165814
# ============================================================

# %% [markdown]
# ---
#
# ## Data Analysis:
#
# Explore the scraped data with these analysis cells:

# %% [markdown]
# ### View Data Info
#
# Check the structure and completeness of the data:

# %%
# View data structure
print("Data shape:", df_hospitals.shape)
print("\nColumn names:")
print(df_hospitals.columns.tolist())
print("\nData types:")
print(df_hospitals.dtypes)
print("\nMissing values:")
print(df_hospitals.isnull().sum())
# Out:
# Data shape: (4088, 30)
#
# Column names:
# ['state_abbr', 'county_name', 'hospital_name', 'city', 'wait_text', 'wait_minutes', 'detail_url', 'detail_name', 'detail_address', 'detail_city', 'detail_state', 'detail_zip', 'detail_phone', 'detail_hospital_type', 'detail_emergency_services', 'detail_mortality_overall_text', 'detail_mortality_overall_percent', 'detail_mortality_overall_direction', 'detail_mortality_heart_attack_percent', 'detail_mortality_stroke_percent', 'detail_mortality_heart_failure_percent', 'detail_mortality_pneumonia_percent', 'detail_c_diff_cases', 'detail_mrsa_cases', 'detail_avg_time_in_ed_minutes', 'detail_overall_patient_rating', 'detail_positive_patient_ratings', 'detail_negative_patient_ratings', 'source_url', 'scrape_ts']
#
# Data types:
# state_abbr                                 object
# county_name                                object
# hospital_name                              object
# city                                       object
# wait_text                                  object
# wait_minutes                              float64
# detail_url                                 object
# detail_name                                object
# detail_address                             object
# detail_city                                object
# detail_state                               object
# detail_zip                                 object
# detail_phone                               object
# detail_hospital_type                       object
# detail_emergency_services                  object
# detail_mortality_overall_text              object
# detail_mortality_overall_percent           object
# detail_mortality_overall_direction         object
# detail_mortality_heart_attack_percent      object
# detail_mortality_stroke_percent            object
# detail_mortality_heart_failure_percent     object
# detail_mortality_pneumonia_percent         object
# detail_c_diff_cases                        object
# detail_mrsa_cases                          object
# detail_avg_time_in_ed_minutes              object
# detail_overall_patient_rating              object
# detail_positive_patient_ratings            object
# detail_negative_patient_ratings            object
# source_url                                 object
# scrape_ts                                  object
# dtype: object
#
# Missing values:
# state_abbr                                   0
# county_name                                  0
# hospital_name                                0
# city                                         0
# wait_text                                    0
# wait_minutes                               371
# detail_url                                   0
# detail_name                                 26
# detail_address                              26
# detail_city                                 26
# detail_state                                26
# detail_zip                                  26
# detail_phone                                26
# detail_hospital_type                        26
# detail_emergency_services                   26
# detail_mortality_overall_text              915
# detail_mortality_overall_percent           915
# detail_mortality_overall_direction         938
# detail_mortality_heart_attack_percent     2317
# detail_mortality_stroke_percent           2152
# detail_mortality_heart_failure_percent    1327
# detail_mortality_pneumonia_percent         950
# detail_c_diff_cases                        534
# detail_mrsa_cases                          572
# detail_avg_time_in_ed_minutes              392
# detail_overall_patient_rating               26
# detail_positive_patient_ratings            988
# detail_negative_patient_ratings            778
# source_url                                   0
# scrape_ts                                    0
# dtype: int64

# %% [markdown]
# ### Top 10 Hospitals by Wait Time
#
# Find hospitals with the shortest ER wait times:

# %%
# Top 10 hospitals with shortest wait times
if "wait_minutes" in df_hospitals.columns:
    top_10 = df_hospitals.nsmallest(10, "wait_minutes")[
        ["hospital_name", "city", "state_abbr", "wait_text", "wait_minutes"]
    ]
    print("Top 10 Hospitals with Shortest Wait Times:")
    print(top_10.to_string(index=False))
else:
    print("Wait time data not available")
# Out:
# Top 10 Hospitals with Shortest Wait Times:
#                     hospital_name          city state_abbr wait_text  wait_minutes
#  Lady Of The Sea General Hospital       Cut Off         LA    0h 45m          45.0
#                 Hopedale Hospital      Hopedale         IL    0h 50m          50.0
#          Big Sandy Medical Center     Big Sandy         MT    0h 53m          53.0
# Mitchell County Hospital District Colorado City         TX    0h 54m          54.0
# Samuel Mahelona Memorial Hospital         Kapaa         HI    0h 56m          56.0
#         Richardson Medical Center      Rayville         LA    0h 58m          58.0
#           Keller Ach (West Point)    West Point         NY     1h 0m          60.0
#     Mercy Hospital Tishomingo Inc    Tishomingo         OK     1h 0m          60.0
#       Mccone County Health Center        Circle         MT     1h 2m          62.0
#                 Sanford Hillsboro     Hillsboro         ND     1h 2m          62.0

# %% [markdown]
# ### State-by-State Comparison
#
# Compare average wait times across states:

# %%
# State-by-state comparison
if "wait_minutes" in df_hospitals.columns and "state_abbr" in df_hospitals.columns:
    state_stats = df_hospitals.groupby("state_abbr")["wait_minutes"].agg([
        ("count", "count"),
        ("avg_wait", "mean"),
        ("min_wait", "min"),
        ("max_wait", "max")
    ]).round(1).sort_values("avg_wait")
    
    print("State-by-State Wait Time Statistics:")
    print(state_stats.to_string())
else:
    print("State comparison data not available")
# Out:
# State-by-State Wait Time Statistics:
#             count  avg_wait  min_wait  max_wait
# state_abbr
# ND             42     111.3      62.0     243.0
# NE             76     118.9      73.0     260.0
# SD             31     121.3      79.0     222.0
# MT             45     123.3      53.0     215.0
# KS             98     123.6      71.0     316.0
# OK             95     124.3      60.0     259.0
# HI             19     126.8      56.0     219.0
# IA             98     127.4      74.0     228.0
# WY             19     130.7      75.0     200.0
# UT             44     134.7      89.0     255.0
# MN            106     136.5      73.0     264.0
# MS             67     137.3      71.0     587.0
# AR             68     137.5      71.0     300.0
# WI            117     138.8      74.0     259.0
# LA             64     140.5      45.0     316.0
# ID             32     140.9      99.0     224.0
# CO             69     143.4      86.0     233.0
# AK             14     145.5     106.0     192.0
# NV             34     147.4      94.0     219.0
# AL             81     151.1      66.0     277.0
# IN            101     151.3      92.0     230.0
# KY             81     152.5      84.0     254.0
# TX            298     153.1      54.0     399.0
# WV             40     153.4      62.0     232.0
# MO             74     154.6      67.0     295.0
# OH            123     164.4      74.0     341.0
# TN             82     165.5      70.0     296.0
# FL            161     166.2      91.0     276.0
# MI            112     166.4      68.0     376.0
# NH             24     168.0      93.0     281.0
# OR             51     169.0      68.0     284.0
# VA             70     169.6     100.0     289.0
# GA            108     169.9      70.0     389.0
# ME             31     170.1     103.0     264.0
# NM             32     172.3      88.0     320.0
# SC             49     173.6      85.0     285.0
# VT              8     180.8     115.0     246.0
# WA             73     182.6      96.0     322.0
# IL            130     185.5      50.0     347.0
# PA            140     186.2      86.0     299.0
# CT             26     189.2      94.0     283.0
# CA            231     189.9      77.0     426.0
# NJ             56     193.8     142.0     348.0
# NC             95     195.6      92.0     454.0
# AZ             56     197.9      83.0     354.0
# NY            136     207.8      60.0     368.0
# DE              6     210.3     136.0     300.0
# MA             55     221.8     124.0     354.0
# RI             10     222.4     112.0     346.0
# MD             39     251.0     145.0     384.0

# %% [markdown]
# ### Mortality Rate Analysis
#
# Analyze hospitals by mortality rates (if enriched data is available):

# %%
# Mortality rate analysis
if "detail_mortality_overall_percent" in df_hospitals.columns:
    mortality_data = df_hospitals[df_hospitals["detail_mortality_overall_percent"].notna()]
    
    if not mortality_data.empty:
        print(f"Hospitals with mortality data: {len(mortality_data)}")
        print(f"\nMortality Rate Statistics:")
        print(f"  Average: {mortality_data['detail_mortality_overall_percent'].mean():.2f}%")
        print(f"  Median: {mortality_data['detail_mortality_overall_percent'].median():.2f}%")
        print(f"  Min: {mortality_data['detail_mortality_overall_percent'].min():.2f}%")
        print(f"  Max: {mortality_data['detail_mortality_overall_percent'].max():.2f}%")
    else:
        print("No mortality data available")
else:
    print("Mortality data not available (enrichment may be disabled)")
# Out:
# Hospitals with mortality data: 3173
#
# Mortality Rate Statistics:
#   Average: 8.44%
#   Median: 7.00%
#   Min: 0.00%
#   Max: 69.00%

# %% [markdown]
# ---
#
# ## Done! 🎉
#
# Your comprehensive hospital data has been scraped and saved.
#
# ### Next Steps:
# 1. Check the output directory for CSV files
# 2. Use the CSV in the app
# 3. Adjust `MAX_COUNTIES` and `ENRICH_DATA` settings to scrape more data
#
# ### Files Generated:
# - `counties_list.csv` - List of all discovered counties
# - `us_hospitals_data_enriched.csv` - Complete hospital data with all metrics
