# %% [markdown]
# ER Wait Times Scraper for HospitalStats.org
#
# This module fetches metro ER pages from HospitalStats.org, parses tabular/ semi-structured HTML into a normalized DataFrame, and outputs these to a csv.

# %%
# import statements
import re, time, csv, argparse, datetime as dt, difflib
from urllib.parse import urljoin
import requests
from pathlib import Path
from bs4 import BeautifulSoup, NavigableString, Tag
from requests.adapters import HTTPAdapter, Retry
import pandas as pd

# %%
MIDWEST_ABBR = {"IL","IN", "IA","KS","MI","MN","MO","NE","ND","OH","SD","WI"} 
US_ABBR = {
    "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA",
    "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD",
    "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ",
    "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC",
    "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"
}

# %% [markdown]
# Scraping the data from Chicago

# %%
# url and headers configuration
BASE_URL  = globals().get("BASE_URL", "https://www.hospitalstats.org")
METRO_URL = globals().get("METRO_URL", "https://www.hospitalstats.org/ER-Wait-Time/Chicago-IL-Metro.htm")
HEADERS   = globals().get("HEADERS", {"User-Agent": "ERWaitTimes/1.0 (+contact@example.com)"})

# %%
# configuration
STAMP      = dt.datetime.utcnow().strftime("%Y%m%d%H%M%S")
OUTDIR     = Path("out") / STAMP
OUTDIR.mkdir(parents=True, exist_ok=True)
DELAY = 0.8

# regex patterns
TIME_RE = re.compile(r'\b(?:(\d+)\s*h)?\s*(\d+)\s*m\b', re.I)
PCT_RE  = re.compile(r'(\d+(?:\.\d+)?)\s*%')
WS      = re.compile(r'\s+')

# %%
# convert (hour, minute) string to integer for minutes
def to_minutes(s: str | None) -> int | None:
    # Convert '2h 15m' or '54m' to minutes, 'N/A' -> None
    if s is None:
        return None
    s = str(s)
    if "N/A" in s:
        return None
    m = TIME_RE.search(s)
    if not m:
        return None
    h = int(m.group(1) or 0)
    mins = int(m.group(2))
    return h * 60 + mins

# %%
# strips and normalizes whitespace
def clean(s): 
    return WS.sub(" ", (s or "").strip())

# %%
# integer to percent 
def to_percent(s):
    if not s: return None
    m = PCT_RE.search(str(s))
    return float(m.group(1)) if m else None

# %%
# GET a URL using a shared Session with retry/backoff and polite headers
def fetch_html(url: str) -> str:
    with requests.Session() as s:
        s.headers.update(HEADERS)
        r = s.get(url, timeout=25)
        r.raise_for_status()
        return r.text

# %%
# try fast-path parsing with pandas.read_html for well-formed tables
def try_read_html_tables(html: str) -> pd.DataFrame | None:
    """
    Try to parse any tables directly with pandas.
    Returns a DataFrame with at least hospital name + wait text if possible.
    """
    try:
        tables = pd.read_html(html) 
    except ValueError:
        return None

    if not tables:
        return None

    # look for a table that lists hospitals & times
    candidates = []
    for t in tables:
        cols_lower = [str(c).lower() for c in t.columns]
        if any("hospital" in c for c in cols_lower) or any("wait" in c for c in cols_lower):
            candidates.append(t)

    if not candidates:
        return None

    # Take the largest table
    df = max(candidates, key=len).copy()
    df.columns = [str(c).strip().lower().replace(" ", "_") for c in df.columns]
    name_col = next((c for c in df.columns if "hospital" in c or c == "name"), None)

    if name_col is None:
        return None

    # Reduce to a minimal schema
    out = pd.DataFrame({
        "hospital_name": df[name_col].astype(str).str.strip(),
    })

    
    return out

# %%
def node_text(n) -> str:
    # Return visible text for any BeautifulSoup node (Tag or string)
    if n is None:
        return ""
    if isinstance(n, NavigableString):
        return str(n)
    if hasattr(n, "get_text"):
        return n.get_text(" ", strip=True)
    return str(n)

def safe_join(parts, sep=" "):
    # Join any list/iterable of nodes/strings safely as text
    return sep.join([node_text(p) for p in parts if p is not None and node_text(p)])

# %%
def bs4_fallback_extract(html: str) -> pd.DataFrame:
    """ Parse a metro page using BeautifulSoup when read_html is unreliable.
    Parameters: 
        html : str
            Raw HTML for a metro ER page (e.g., Chicago-IL-Metro).

    Returns:
        pd.DataFrame
            Frame with normalized columns such as:
            - 'Hospital'
            - 'City'
            - 'State'
            - 'WaitMinutes' (int or None)
            - 'LeftBeforeSeen' (float % or None)
            - 'NotRecommended' (float % or None) """
    if BeautifulSoup is None:
        raise RuntimeError("BeautifulSoup not installed; `pip install beautifulsoup4` or rely on read_html tables.")

    from urllib.parse import urljoin
    soup = BeautifulSoup(html, "html.parser")

    # Hospital links: /hospital-ratings/....
    links = soup.select('a[href*="/hospital-ratings/"]')
    rows = []
    # "Comment <City> <Wait/N/A>"
    row_re = re.compile(r'Comment\s+(.*?)\s+(?:(\d+\s*h\s*\d+\s*m|\d+\s*m)|N/A)\b', re.I)

    for a in links:
        name = a.get_text(strip=True)
        href = urljoin(BASE_URL, a.get("href","").strip())

        parent_text = a.parent.get_text(" ", strip=True)
        tail = parent_text.replace(name, "", 1).strip()
        m = row_re.search(tail)

        city = m.group(1).strip() if m else None
        wait_text = (m.group(2).strip() if (m and m.group(2)) else "N/A")

        rows.append({
            "hospital_name": name,
            "city": city,
            "wait_text": wait_text,
            "wait_minutes": to_minutes(wait_text),
            "detail_url": href,          
        })

    return pd.DataFrame(rows)

# %%
# find the text that follows a bold/label element within a soup tree
def text_after_b(soup, label_regex):
    """
    Find <b>Label:</b> VALUE in the same parent; collect text from following
    siblings up to the first <br>. Robust to Tag objects.
    Parameters:
        soup: bs4.BeautifulSoup | Tag
        label_regex: Pattern[str]
    """
    for b in soup.find_all("b"):
        if re.search(label_regex, b.get_text(" ", strip=True), re.I):
            parts = []
            for sib in b.next_siblings:
                if isinstance(sib, Tag) and sib.name == "br":
                    break
                parts.append(sib)
            txt = clean(safe_join(parts))
            if txt:
                return txt
    return None

# %%
# create a normalized key for hospital names to improve joins across pages
def norm_name(s: str) -> str:
    if not s: return ""
    s = s.strip()
    s = re.sub(r'(?i)\s*comment\s*$', '', s)  
    s = re.sub(r'\s+', ' ', s)             
    s = re.sub(r"[’'`]", "", s)         
    return s.lower()

# %%
def series_or_na(frame: pd.DataFrame, col: str) -> pd.Series:
    # Return frame[col] if it exists, else a NA Series aligned to frame.index
    return frame[col] if col in frame.columns else pd.Series(pd.NA, index=frame.index)

# %%
# annotate the metro DataFrame with per-hospital detail page URLs
def attach_detail_urls(html: str, df: pd.DataFrame) -> pd.DataFrame:
    soup = BeautifulSoup(html, "html.parser")
    anchors = soup.select('a[href*="/hospital-ratings/"]')
    link_rows = []
    for a in anchors:
        text = a.get_text(strip=True)
        href = (a.get("href") or "").strip()
        if text and href:
            link_rows.append({
                "__key": norm_name(text),
                "anchor_name": text,
                "detail_url_from_anchor": urljoin(BASE_URL, href),
            })
    df_links = pd.DataFrame(link_rows).drop_duplicates(subset="__key")

    # Clean names and key
    if "hospital_name" not in df.columns:
        raise RuntimeError("Need a 'hospital_name' column on df.")
    df = df.copy()
    df["hospital_name"] = (
        df["hospital_name"].astype(str)
          .str.replace(r'(?i)\s*comment\s*$', '', regex=True)
          .str.strip()
    )
    df["__key"] = df["hospital_name"].map(norm_name)

    # Safe merge
    if "detail_url" in df.columns:
        df = df.rename(columns={"detail_url": "detail_url_existing"})

    df = df.merge(df_links[["__key", "anchor_name", "detail_url_from_anchor"]],
                  on="__key", how="left")
    df["hospital_name"] = df["anchor_name"].fillna(df["hospital_name"])
    existing = series_or_na(df, "detail_url_existing")
    df["detail_url"] = df["detail_url_from_anchor"].where(df["detail_url_from_anchor"].notna(), existing)

    # Cleanup
    for col in ["anchor_name", "detail_url_from_anchor", "detail_url_existing"]:
        if col in df.columns:
            df.drop(columns=[col], inplace=True)
    return df

# %%
html = requests.get(METRO_URL, headers=HEADERS, timeout=25).text
soup = BeautifulSoup(html, "html.parser")

# read tables and pick the one with a Hospital column
tables = pd.read_html(html)
base = None
for t in tables:
    cols = [str(c).lower() for c in t.columns.astype(str)]
    if any("hospital" in c for c in cols):
        base = t.copy(); break
if base is None:
    raise RuntimeError("Could not find the hospital table on the metro page.")

# normalize and keep core fields
base.columns = [str(c).strip().lower().replace("name", "hospital_name") for c in base.columns]
name_col = [c for c in base.columns if "hospital" in c][0]
city_col = next((c for c in base.columns if "city" in c), None)
wait_col = next((c for c in base.columns if "wait" in c and "time" in c), None)

df = pd.DataFrame({
    "hospital_name": base[name_col].astype(str).str.strip(),
    "city": base[city_col] if city_col else pd.NA,
    "wait_text": base[wait_col] if wait_col else pd.NA,
})
df["wait_minutes"] = df["wait_text"].apply(to_minutes)

# attach detail_url from anchors
anchors = soup.select('a[href*="/hospital-ratings/"]')
link_rows = []
for a in anchors:
    text = a.get_text(strip=True)
    href = (a.get("href") or "").strip()
    if text and href:
        link_rows.append({
            "__key": norm_name(text),
            "anchor_name": text,
            "detail_url": urljoin(BASE_URL, href),
        })
df_links = pd.DataFrame(link_rows).drop_duplicates(subset="__key")

df["hospital_name"] = df["hospital_name"].str.replace(r'(?i)\s*comment\s*$', '', regex=True).str.strip()
df["__key"] = df["hospital_name"].map(norm_name)
df = df.merge(df_links, on="__key", how="left")
df["hospital_name"] = df["anchor_name"].fillna(df["hospital_name"])
df.drop(columns=["anchor_name","__key"], inplace=True)

# write staging + timeseries
now_iso = dt.datetime.now(dt.timezone.utc).isoformat()
df["scrape_ts"] = now_iso
df["source_url"] = METRO_URL

staging = pd.DataFrame({
    "source": "hospitalstats",
    "name": df["hospital_name"],
    "city": df["city"],
    "wait_minutes": df["wait_minutes"].astype("Int64"),
    "source_url": df["source_url"],
    "detail_url": df["detail_url"],
    "raw_wait_text": df["wait_text"],
    "scrape_ts": df["scrape_ts"],
})

timeseries = pd.DataFrame({
    "source": staging["source"],
    "name": staging["name"],
    "city": staging["city"],
    "ts": staging["scrape_ts"],
    "wait_minutes": staging["wait_minutes"],
    "source_url": staging["source_url"],
})

stamp = dt.datetime.utcnow().strftime("%Y%m%d%H%M%S")
outdir = Path("out") / stamp
outdir.mkdir(parents=True, exist_ok=True)

staging.to_csv(outdir / "staging_chicago.csv", index=False)
timeseries.to_csv(outdir / "wait_times_timeseries.csv", index=False)
staging.to_csv("staging_chicago.csv", index=False)
timeseries.to_csv("wait_times_timeseries.csv", index=False)
# Out:
# C:\Users\Rifa\AppData\Local\Temp\ipykernel_22792\4095769453.py:5: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# C:\Users\Rifa\AppData\Local\Temp\ipykernel_22792\4095769453.py:72: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   stamp = dt.datetime.utcnow().strftime("%Y%m%d%H%M%S")

# %%
# Extract additional metrics from a hospital's detail page:
def parse_detail_page(html: str, url: str) -> dict:
    """ 
        address, phone, hospital type, emergency services,
        mortality rates (overall, heart attack, stroke, heart failure, pneumonia),
        infection cases (C. Diff, MRSA),
        average ER wait time,
        patient ratings (overall, positive points, negative points)
    """
    soup = BeautifulSoup(html, "html.parser")
    h1 = soup.find(["h1","h2"])
    name = clean(h1.get_text(" ", strip=True)) if h1 else None

    # address/phone block
    address=city=state=postal=phone=None
    left = soup.select('div[style*="float:left"][style*="width:40%"]')
    if left:
        addr_html = left[0]
        lines = [x for x in addr_html.get_text("\n", strip=True).split("\n") if x]
        if lines: address = clean(lines[0])
        if len(lines)>=2:
            m = re.search(r"(.+?),\s*([A-Z]{2})\s+(\d{5}(?:-\d{4})?)", lines[1])
            if m: city, state, postal = clean(m.group(1)), m.group(2), m.group(3)
        b_phone = addr_html.find("b", string=re.compile(r"^\s*Phone\s*:\s*$", re.I))
        if b_phone:
            parts = []
            for sib in b_phone.next_siblings:
                if isinstance(sib, Tag) and sib.name == "br":
                    break
                parts.append(sib)
            maybe_phone = safe_join(parts)          
            pm = re.search(r"\(?\d{3}\)?[ -]?\d{3}[ -]?\d{4}", maybe_phone)
            if pm:
                phone = pm.group(0)

    hosp_type = text_after_b(soup, r"Hospital\s*Type")
    emergency_services = text_after_b(soup, r"Emergency\s*Services")
    if emergency_services:
        es = emergency_services.upper()
        emergency_services = "YES" if "YES" in es else ("NO" if "NO" in es else emergency_services)

    # quality section
    quality_hdr = soup.find(id="Quality")
    mort_text=mort_pct=mort_dir=None
    ha=st=hf=pn=None
    if quality_hdr:
        span = quality_hdr.find_next("span", class_="bigstat")
        if span:
            mort_text = clean(span.get_text(" ", strip=True))
            m = re.search(r"(\d+(?:\.\d+)?)\s*%", mort_text);  mort_pct = float(m.group(1)) if m else None
            d = re.search(r"\b(better|worse)\b", mort_text, re.I); mort_dir = d.group(1).lower() if d else None
        tbl = quality_hdr.find_next("table")
        if tbl:
            for tr in tbl.find_all("tr"):
                th = tr.find("th"); tds = tr.find_all("td")
                if not th or not tds: continue
                label = clean(th.get_text(" ", strip=True))
                pct = to_percent(tds[0].get_text(" ", strip=True))
                if   re.search(r"Heart Attack", label, re.I): ha = pct
                elif re.search(r"Stroke", label, re.I):       st = pct
                elif re.search(r"Heart Failure", label, re.I): hf = pct
                elif re.search(r"Pneumonia", label, re.I):     pn = pct

    # infections
    c_diff=mrsa=None
    inf = soup.find(id="infectious")
    if inf:
        tbl = inf.find_next("table")
        if tbl:
            for tr in tbl.find_all("tr"):
                tds = tr.find_all("td")
                if len(tds)!=2: continue
                label = tds[0].get_text(" ", strip=True)
                val = re.sub(r"[^\d]","", tds[1].get_text(" ", strip=True)) or None
                val = int(val) if val else None
                if re.search(r"C\.\s*Diff", label, re.I): c_diff = val
                if re.search(r"MRSA", label, re.I):       mrsa   = val

    # ER wait
    avg_ed_min=None
    er = soup.find(id="erwait")
    if er:
        span = (er.find_parent() or er).find("span","bigstat")
        if span: avg_ed_min = to_minutes(span.get_text(" ", strip=True))

    # patient ratings
    overall_patient_rating = None
    positive_points = negative_points = None

    pr_hdr = soup.find(id="patientratings")
    if pr_hdr:
        # Overall rating 
        span = pr_hdr.find_next("span", class_="bigstat")
        if span:
            overall_patient_rating = clean(span.get_text(" ", strip=True))

        # positive box
        pos_h3 = soup.find("h3", string=re.compile(r"Positive\s+Patient\s+Ratings", re.I))
        if pos_h3:
            pos_box = pos_h3.find_parent("div")
            if pos_box:
                ul = pos_box.find("ul") 
                if ul and ul.find_all("li"):
                    positive_points = "; ".join(
                        clean(li.get_text(" ", strip=True)) for li in ul.find_all("li")
                    )
                else:
                    # Some pages have no <ul>, just "No consistently positive ratings"
                    raw = clean(pos_box.get_text(" ", strip=True))
                    raw = re.sub(r"^\s*Positive\s+Patient\s+Ratings\s*", "", raw, flags=re.I).strip()
                    if re.search(r"No\s+consistently\s+positive\s+ratings", raw, re.I):
                        positive_points = None  
                    elif raw:
                        positive_points = raw  

        # negative box 
        neg_h3 = soup.find("h3", string=re.compile(r"Negative\s+Patient\s+Ratings", re.I))
        if neg_h3:
            neg_box = neg_h3.find_parent("div")
            if neg_box:
                ul = neg_box.find("ul")
                if ul and ul.find_all("li"):
                    negative_points = "; ".join(
                        clean(li.get_text(" ", strip=True)) for li in ul.find_all("li")
                    )

        # Safety: if positive == negative (selector leak), blank out positive
        if positive_points and negative_points and positive_points == negative_points:
            positive_points = None

    return {
        "detail_url": url,
        "detail_name": name,
        "detail_address": address, "detail_city": city, "detail_state": state, "detail_zip": postal, "detail_phone": phone,
        "detail_hospital_type": hosp_type,
        "detail_emergency_services": emergency_services,
        "detail_mortality_overall_text": mort_text,
        "detail_mortality_overall_percent": mort_pct,
        "detail_mortality_overall_direction": mort_dir,
        "detail_mortality_heart_attack_percent": ha,
        "detail_mortality_stroke_percent": st,
        "detail_mortality_heart_failure_percent": hf,
        "detail_mortality_pneumonia_percent": pn,
        "detail_c_diff_cases": c_diff,
        "detail_mrsa_cases": mrsa,
        "detail_avg_time_in_ed_minutes": avg_ed_min,
        "detail_overall_patient_rating": overall_patient_rating,
        "detail_positive_patient_ratings": positive_points,
        "detail_negative_patient_ratings": negative_points,
    }

# %%
# visit each row's 'detail_url' (if present) and enrich the DataFrame in place
def enrich_df_inline(df: pd.DataFrame, delay: float = 0.8) -> pd.DataFrame:
    """ 
    Parameters
        df : pd.DataFrame
            Frame expected to contain a 'detail_url' column with absolute URLs.
        delay : float, default 0.8
            Sleep duration between requests to avoid overloading the site.
    Returns
        pd.DataFrame
            A new DataFrame with added/updated columns from detail pages.
    """
    if "detail_url" not in df.columns:
        raise ValueError("DataFrame must contain a 'detail_url' column.")
    urls = df["detail_url"].dropna().astype(str).unique().tolist()
    rows = []
    with requests.Session() as s:
        s.headers.update(HEADERS)
        for i, url in enumerate(urls, 1):
            try:
                time.sleep(delay)
                r = s.get(url, timeout=30)
                r.raise_for_status()
                rows.append(parse_detail_page(r.text, url))
            except Exception as e:
                rows.append({"detail_url": url, "detail_error": str(e)})
            print(f"[{i}/{len(urls)}] {url}")
    df_detail = pd.DataFrame(rows)
    return df.merge(df_detail, on="detail_url", how="left")

df_staging = pd.read_csv("staging_chicago.csv")
df_enriched = enrich_df_inline(df_staging, delay=0.8)
df_enriched.to_csv("staging_chicago_enriched.csv", index=False)
df_enriched.to_csv(outdir / "staging_chicago_enriched.csv", index=False)
# Out:
# [1/30] https://www.hospitalstats.org/hospital-ratings/presence-saint-joseph-hospital--chicago-chicago-il.htm
# [2/30] https://www.hospitalstats.org/hospital-ratings/loretto-hospital-chicago-il.htm
# [3/30] https://www.hospitalstats.org/hospital-ratings/thorek-memorial-hospital-chicago-il.htm
# [4/30] https://www.hospitalstats.org/hospital-ratings/insight-hospital-and-medical-center-chicago-chicago-il.htm
# [5/30] https://www.hospitalstats.org/hospital-ratings/holy-cross-hospital-chicago-il.htm
# [6/30] https://www.hospitalstats.org/hospital-ratings/jackson-park-hospital-chicago-il.htm
# [7/30] https://www.hospitalstats.org/hospital-ratings/humboldt-park-health-chicago-il.htm
# [8/30] https://www.hospitalstats.org/hospital-ratings/provident-hospital-of-chicago-chicago-il.htm
# [9/30] https://www.hospitalstats.org/hospital-ratings/saint-anthony-hospital-chicago-il.htm
# [10/30] https://www.hospitalstats.org/hospital-ratings/methodist-hospital-of-chicago-chicago-il.htm
# [11/30] https://www.hospitalstats.org/hospital-ratings/mt-sinai-hospital-medical-center-chicago-il.htm
# [12/30] https://www.hospitalstats.org/hospital-ratings/presence-saints-mary-and-elizabeth-medical-center-chicago-il.htm
# [13/30] https://www.hospitalstats.org/hospital-ratings/community-first-medical-center-chicago-il.htm
# [14/30] https://www.hospitalstats.org/hospital-ratings/louis-a-weiss-memorial-hospital-chicago-il.htm
# [15/30] https://www.hospitalstats.org/hospital-ratings/advocate-illinois-masonic-medical-center-chicago-il.htm
# [16/30] https://www.hospitalstats.org/hospital-ratings/amita-health-resurrection-medical-center-chicago-il.htm
# [17/30] https://www.hospitalstats.org/hospital-ratings/roseland-community-hospital-chicago-il.htm
# [18/30] https://www.hospitalstats.org/hospital-ratings/advocate-trinity-hospital-chicago-il.htm
# [19/30] https://www.hospitalstats.org/hospital-ratings/south-shore-hospital-chicago-il.htm
# [20/30] https://www.hospitalstats.org/hospital-ratings/swedish-hospital-chicago-il.htm
# [21/30] https://www.hospitalstats.org/hospital-ratings/john-h-stroger-jr-hospital-chicago-il.htm
# [22/30] https://www.hospitalstats.org/hospital-ratings/the-university-of-chicago-medical-center-chicago-il.htm
# [23/30] https://www.hospitalstats.org/hospital-ratings/st-bernard-hospital-chicago-il.htm
# [24/30] https://www.hospitalstats.org/hospital-ratings/rush-university-medical-center-chicago-il.htm
# [25/30] https://www.hospitalstats.org/hospital-ratings/university-of-illinois-hospital-and-clinics-chicago-il.htm
# [26/30] https://www.hospitalstats.org/hospital-ratings/northwestern-memorial-hospital-chicago-il.htm
# [27/30] https://www.hospitalstats.org/hospital-ratings/jesse-brown-va-medical-center--va-chicago-healthcare-system-chicago-il.htm
# [28/30] https://www.hospitalstats.org/hospital-ratings/ann-robert-h-lurie-childrens-hospital-of-chicago-chicago-il.htm
# [29/30] https://www.hospitalstats.org/hospital-ratings/hartgrove-hospital-chicago-il.htm
# [30/30] https://www.hospitalstats.org/hospital-ratings/montrose-behavioral-health-hospital-chicago-il.htm

# %% [markdown]
# Scraping for the Midwest

# %%
BASE_URL_MIDWEST = "https://www.hospitalstats.org/ER-Wait-Time/"

def get_midwest_state_links(base_url: str = BASE_URL_MIDWEST) -> pd.DataFrame:
    """Build the table: state_abbr + absolute link to '<ABBR>-Counties.htm'."""
    r = requests.get(base_url, timeout=30, headers={"User-Agent": "MidwestERScraper/1.0"})
    r.raise_for_status()
    soup = BeautifulSoup(r.text, "html.parser")

    # Find the section with the state list
    container = None
    for h3 in soup.find_all("h3"):
        if "Browse Emergency Room Stats by State" in h3.get_text(strip=True):
            container = h3.parent
            break
    anchors = container.find_all("a", href=True) if container else soup.find_all("a", href=True)

    rows = []
    for a in anchors:
        href = a["href"]
        # Looks like "IL-Counties.htm"
        if re.fullmatch(r"[A-Z]{2}-Counties\.htm", href):
            abbr = a.get_text(strip=True).upper() or href.split("-")[0]
            if abbr in MIDWEST_ABBR:
                rows.append({
                    "state_abbr": abbr,
                    "midwest_state_link": urljoin(base_url, href)
                })
    return pd.DataFrame(rows).drop_duplicates().sort_values("state_abbr").reset_index(drop=True)

def discover_counties_for_state(state_abbr: str, state_url: str) -> pd.DataFrame:
    """
    For a given state '<ABBR>-Counties.htm' page, return county name + absolute URL.
    It targets anchors like:
        <a href="Ada-County-ID.htm">Ada</a>
    """
    r = requests.get(state_url, timeout=30, headers={"User-Agent": "MidwestERScraper/1.0"})
    r.raise_for_status()
    soup = BeautifulSoup(r.text, "html.parser")

    # Focus on the main content area if present; fallback to whole page
    content = soup.find(id="content") or soup
    out = []
    for a in content.find_all("a", href=True):
        href = a["href"]
        name = a.get_text(" ", strip=True)
        # County links typically contain "-County-" and end with ".htm"
        if "-County-" in href and href.lower().endswith(".htm"):
            out.append({
                "state_abbr": state_abbr,
                "county_name": name,
                "county_url": urljoin(BASE_URL, href)
            })
    return pd.DataFrame(out).drop_duplicates(subset=["county_url"]).reset_index(drop=True)

def build_midwest_counties_df(include_county_page_html: bool = False) -> pd.DataFrame:
    """
    1) Gets the Midwest states table (abbr + link)
    2) Visits each state page to list counties (name + absolute URL)
    3) Optionally fetches every county page HTML into a 'county_html' column
    """
    df_states = get_midwest_state_links()
    all_parts = []
    for _, row in df_states.iterrows():
        part = discover_counties_for_state(row["state_abbr"], row["midwest_state_link"])
        all_parts.append(part)
    df_counties = pd.concat(all_parts, ignore_index=True) if all_parts else pd.DataFrame(
        columns=["state_abbr","county_name","county_url"]
    )

    if include_county_page_html and not df_counties.empty:
        htmls = []
        for u in df_counties["county_url"].tolist():
            rr = requests.get(u, timeout=30, headers={"User-Agent": "MidwestERScraper/1.0"})
            rr.raise_for_status()
            htmls.append(rr.text)
        df_counties["county_html"] = htmls

    return df_counties

# Table of Midwest counties with names + absolute URLs:
df_midwest_counties = build_midwest_counties_df(include_county_page_html=False)
df_midwest_counties.head(10)
# Out:
#   state_abbr  county_name                                         county_url
# 0         IA        Adair  https://www.hospitalstats.org/Adair-County-IA.htm
# 1         IA        Adams  https://www.hospitalstats.org/Adams-County-IA.htm
# 2         IA    Allamakee  https://www.hospitalstats.org/Allamakee-County...
# 3         IA    Appanoose  https://www.hospitalstats.org/Appanoose-County...
# 4         IA      Audubon  https://www.hospitalstats.org/Audubon-County-I...
# 5         IA   Black Hawk  https://www.hospitalstats.org/Black-Hawk-Count...
# 6         IA        Boone  https://www.hospitalstats.org/Boone-County-IA.htm
# 7         IA       Bremer  https://www.hospitalstats.org/Bremer-County-IA...
# 8         IA     Buchanan  https://www.hospitalstats.org/Buchanan-County-...
# 9         IA  Buena Vista  https://www.hospitalstats.org/Buena-Vista-Coun...

# %%
def parse_county(county_url: str, county_html: str | None = None, delay: float = 0.8):
    """
    Return an enriched DataFrame for one county by:
      1) parsing hospitals from county HTML (read_html fast-path, else BS4 fallback)
      2) attaching detail page URLs
      3) visiting each detail page to enrich metrics
    """
    html = county_html if county_html is not None else fetch_html(county_url)

    # 1) county hospitals list
    df = try_read_html_tables(html)
    if df is None or getattr(df, "empty", True):
        df = bs4_fallback_extract(html)

    # 2) attach detail page links & 3) enrich in-line
    df = attach_detail_urls(html, df)
    df_enriched = enrich_df_inline(df, delay=delay)
    return df_enriched

# %%
county_frames = {}  
errors = []

for i, row in df_midwest_counties.iterrows():
    state_abbr = row["state_abbr"]
    county_name = row["county_name"]
    county_url  = row["county_url"]
    county_html = row.get("county_html", None)

    key = (state_abbr, county_name)
    try:
        df_enriched = parse_county(county_url, county_html=county_html, delay=0.8)
        # stamp county/state context onto each row for downstream grouping/filters
        if not df_enriched.empty:
            df_enriched = df_enriched.copy()
            if "State" not in df_enriched.columns:
                df_enriched["State"] = state_abbr  # harmonize with existing schema
            if "County" not in df_enriched.columns:
                df_enriched["County"] = county_name
        county_frames[key] = df_enriched

        print(f"[OK] {state_abbr} – {county_name}: {len(df_enriched)} rows")

    except Exception as e:
        errors.append({"state_abbr": state_abbr, "county_name": county_name,
                       "county_url": county_url, "error": str(e)[:500]})
        print(f"[ERR] {state_abbr} – {county_name}: {e}")

# %%
if county_frames:
    df_all_midwest_hospitals = pd.concat(
        [v for v in county_frames.values() if v is not None],
        ignore_index=True
    )
else:
    df_all_midwest_hospitals = pd.DataFrame()

print("All Midwest hospitals:", df_all_midwest_hospitals.shape)
if not df_all_midwest_hospitals.empty:
    if "detail_error" in df_all_midwest_hospitals.columns:
        df_all_midwest_hospitals = df_all_midwest_hospitals[
            df_all_midwest_hospitals["detail_error"].isna() | (df_all_midwest_hospitals["detail_error"] == "")
        ].drop(columns=["detail_error"])
    if "hospital" in df_all_midwest_hospitals.columns:
        df_all_midwest_hospitals = df_all_midwest_hospitals[
            df_all_midwest_hospitals["hospital"].notna() & (df_all_midwest_hospitals["hospital"].astype(str).str.strip() != "")
        ].reset_index(drop=True)
df_all_midwest_hospitals.head(20)
#export as a CSV
df_all_midwest_hospitals.to_csv("midwest_hospitals_enriched.csv", index=False)
# Out:
# All Midwest hospitals: (1059, 27)
# C:\Users\Rifa\AppData\Local\Temp\ipykernel_22792\142911147.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_all_midwest_hospitals = pd.concat(

# %% [markdown]
# # Scrape all US:

# %%
BASE_URL_US = "https://www.hospitalstats.org/ER-Wait-Time/"

def get_united_state_links(base_url: str = BASE_URL_US) -> pd.DataFrame:
    """Build the table: state_abbr + absolute link to '<ABBR>-Counties.htm'."""
    r = requests.get(base_url, timeout=30, headers={"User-Agent": "USERScraper/1.0"})
    r.raise_for_status()
    soup = BeautifulSoup(r.text, "html.parser")

    # Find the section with the state list
    container = None
    for h3 in soup.find_all("h3"):
        if "Browse Emergency Room Stats by State" in h3.get_text(strip=True):
            container = h3.parent
            break
    anchors = container.find_all("a", href=True) if container else soup.find_all("a", href=True)

    rows = []
    for a in anchors:
        href = a["href"]
        # Looks like "IL-Counties.htm"
        if re.fullmatch(r"[A-Z]{2}-Counties\.htm", href):
            abbr = a.get_text(strip=True).upper() or href.split("-")[0]
            if abbr in US_ABBR:
                rows.append({
                    "state_abbr": abbr,
                    "united_state_link": urljoin(base_url, href)
                })
    return pd.DataFrame(rows).drop_duplicates().sort_values("state_abbr").reset_index(drop=True)

def discover_counties_for_state(state_abbr: str, state_url: str) -> pd.DataFrame:
    """
    For a given state '<ABBR>-Counties.htm' page, return county name + absolute URL.
    It targets anchors like:
        <a href="Ada-County-ID.htm">Ada</a>
    """
    r = requests.get(state_url, timeout=30, headers={"User-Agent": "USERScraper/1.0"})
    r.raise_for_status()
    soup = BeautifulSoup(r.text, "html.parser")

    # Focus on the main content area if present; fallback to whole page
    content = soup.find(id="content") or soup
    out = []
    for a in content.find_all("a", href=True):
        href = a["href"]
        name = a.get_text(" ", strip=True)
        # County links typically contain "-County-" and end with ".htm"
        if "-County-" in href and href.lower().endswith(".htm"):
            out.append({
                "state_abbr": state_abbr,
                "county_name": name,
                "county_url": urljoin(BASE_URL, href)
            })
    return pd.DataFrame(out).drop_duplicates(subset=["county_url"]).reset_index(drop=True)

def build_united_counties_df(include_county_page_html: bool = False) -> pd.DataFrame:
    """
    1) Gets the United States table (abbr + link)
    2) Visits each state page to list counties (name + absolute URL)
    3) Optionally fetches every county page HTML into a 'county_html' column
    """
    df_states = get_united_state_links()
    all_parts = []
    for _, row in df_states.iterrows():
        part = discover_counties_for_state(row["state_abbr"], row["united_state_link"])
        all_parts.append(part)
    df_counties = pd.concat(all_parts, ignore_index=True) if all_parts else pd.DataFrame(
        columns=["state_abbr","county_name","county_url"]
    )

    if include_county_page_html and not df_counties.empty:
        htmls = []
        for u in df_counties["county_url"].tolist():
            rr = requests.get(u, timeout=30, headers={"User-Agent": "USERScraper/1.0"})
            rr.raise_for_status()
            htmls.append(rr.text)
        df_counties["county_html"] = htmls

    return df_counties

# Table of US counties with names + absolute URLs:
df_united_counties = build_united_counties_df(include_county_page_html=False)
df_united_counties.head(10)
# Out:
#   state_abbr           county_name  \
# 0         AK
# 1         AK             Anchorage
# 2         AK                Bethel
# 3         AK            Dillingham
# 4         AK  Fairbanks North Star
# 5         AK                Juneau
# 6         AK       Kenai Peninsula
# 7         AK     Ketchikan Gateway
# 8         AK         Kodiak Island
# 9         AK     Matanuska Susitna
#
#                                           county_url
# 0       https://www.hospitalstats.org/-County-AK.htm
# 1  https://www.hospitalstats.org/Anchorage-County...
# 2  https://www.hospitalstats.org/Bethel-County-AK...
# 3  https://www.hospitalstats.org/Dillingham-Count...
# 4  https://www.hospitalstats.org/Fairbanks-North-...
# 5  https://www.hospitalstats.org/Juneau-County-AK...
# 6  https://www.hospitalstats.org/Kenai-Peninsula-...
# 7  https://www.hospitalstats.org/Ketchikan-Gatewa...
# 8  https://www.hospitalstats.org/Kodiak-Island-Co...
# 9  https://www.hospitalstats.org/Matanuska-Susitn...

# %%
def parse_county(county_url: str, county_html: str | None = None, delay: float = 0.8):
    """
    Return an enriched DataFrame for one county by:
      1) parsing hospitals from county HTML (read_html fast-path, else BS4 fallback)
      2) attaching detail page URLs
      3) visiting each detail page to enrich metrics
    """
    html = county_html if county_html is not None else fetch_html(county_url)

    # 1) county hospitals list
    df = try_read_html_tables(html)
    if df is None or getattr(df, "empty", True):
        df = bs4_fallback_extract(html)

    # 2) attach detail page links & 3) enrich in-line
    df = attach_detail_urls(html, df)
    df_enriched = enrich_df_inline(df, delay=delay)
    return df_enriched

# %%
county_frames = {}  
errors = []

for i, row in df_united_counties.iterrows():
    state_abbr = row["state_abbr"]
    county_name = row["county_name"]
    county_url  = row["county_url"]
    county_html = row.get("county_html", None)

    key = (state_abbr, county_name)
    try:
        df_enriched = parse_county(county_url, county_html=county_html, delay=0.8)
        # stamp county/state context onto each row for downstream grouping/filters
        if not df_enriched.empty:
            df_enriched = df_enriched.copy()
            if "State" not in df_enriched.columns:
                df_enriched["State"] = state_abbr  # harmonize with existing schema
            if "County" not in df_enriched.columns:
                df_enriched["County"] = county_name
        county_frames[key] = df_enriched

        print(f"[OK] {state_abbr} – {county_name}: {len(df_enriched)} rows")

    except Exception as e:
        errors.append({"state_abbr": state_abbr, "county_name": county_name,
                       "county_url": county_url, "error": str(e)[:500]})
        print(f"[ERR] {state_abbr} – {county_name}: {e}")
# Out:
# [ERR] AK – : 404 Client Error: Not Found for url: https://www.hospitalstats.org/-County-AK.htm
# [ERR] AK – Anchorage: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Anchorage-County-AK.htm
# [ERR] AK – Bethel: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Bethel-County-AK.htm
# [ERR] AK – Dillingham: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Dillingham-County-AK.htm
# [ERR] AK – Fairbanks North Star: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Fairbanks-North-Star-County-AK.htm
# [ERR] AK – Juneau: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Juneau-County-AK.htm
# [ERR] AK – Kenai Peninsula: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Kenai-Peninsula-County-AK.htm
# [ERR] AK – Ketchikan Gateway: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Ketchikan-Gateway-County-AK.htm
# [ERR] AK – Kodiak Island: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Kodiak-Island-County-AK.htm
# [ERR] AK – Matanuska Susitna: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Matanuska-Susitna-County-AK.htm
# [ERR] AK – Nome: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Nome-County-AK.htm
# [ERR] AK – Sitka: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Sitka-County-AK.htm
# [ERR] AK – Valdez Cordova: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Valdez-Cordova-County-AK.htm
# [ERR] AL – Autauga: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Autauga-County-AL.htm
# [ERR] AL – Baldwin: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Baldwin-County-AL.htm
# [ERR] AL – Barbour: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Barbour-County-AL.htm
# [ERR] AL – Bibb: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Bibb-County-AL.htm
# [ERR] AL – Blount: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Blount-County-AL.htm
# [ERR] AL – Bullock: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Bullock-County-AL.htm
# [ERR] AL – Butler: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Butler-County-AL.htm
# [ERR] AL – Calhoun: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Calhoun-County-AL.htm
# [ERR] AL – Chambers: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Chambers-County-AL.htm
# [ERR] AL – Cherokee: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Cherokee-County-AL.htm
# [ERR] AL – Chilton: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Chilton-County-AL.htm
# [ERR] AL – Clarke: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Clarke-County-AL.htm
# [ERR] AL – Clay: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Clay-County-AL.htm
# [ERR] AL – Coffee: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Coffee-County-AL.htm
# [ERR] AL – Colbert: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Colbert-County-AL.htm
# [ERR] AL – Conecuh: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Conecuh-County-AL.htm
# [ERR] AL – Covington: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Covington-County-AL.htm
# [ERR] AL – Crenshaw: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Crenshaw-County-AL.htm
# [ERR] AL – Cullman: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Cullman-County-AL.htm
# [ERR] AL – Dale: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Dale-County-AL.htm
# [ERR] AL – Dallas: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Dallas-County-AL.htm
# [ERR] AL – De Kalb: 404 Client Error: Not Found for url: https://www.hospitalstats.org/De-Kalb-County-AL.htm
# [ERR] AL – Elmore: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Elmore-County-AL.htm
# [ERR] AL – Escambia: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Escambia-County-AL.htm
# [ERR] AL – Etowah: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Etowah-County-AL.htm
# [ERR] AL – Fayette: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Fayette-County-AL.htm
# [ERR] AL – Franklin: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Franklin-County-AL.htm
# [ERR] AL – Geneva: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Geneva-County-AL.htm
# [ERR] AL – Greene: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Greene-County-AL.htm
# [ERR] AL – Hale: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Hale-County-AL.htm
# [ERR] AL – Houston: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Houston-County-AL.htm
# [ERR] AL – Jackson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Jackson-County-AL.htm
# [ERR] AL – Jefferson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Jefferson-County-AL.htm
# [ERR] AL – Lauderdale: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lauderdale-County-AL.htm
# [ERR] AL – Lawrence: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lawrence-County-AL.htm
# [ERR] AL – Lee: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lee-County-AL.htm
# [ERR] AL – Limestone: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Limestone-County-AL.htm
# [ERR] AL – Madison: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Madison-County-AL.htm
# [ERR] AL – Marengo: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Marengo-County-AL.htm
# [ERR] AL – Marion: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Marion-County-AL.htm
# [ERR] AL – Marshall: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Marshall-County-AL.htm
# [ERR] AL – Mobile: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Mobile-County-AL.htm
# [ERR] AL – Monroe: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Monroe-County-AL.htm
# [ERR] AL – Montgomery: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Montgomery-County-AL.htm
# [ERR] AL – Morgan: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Morgan-County-AL.htm
# [ERR] AL – Pickens: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pickens-County-AL.htm
# [ERR] AL – Pike: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pike-County-AL.htm
# [ERR] AL – Randolph: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Randolph-County-AL.htm
# [ERR] AL – Russell: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Russell-County-AL.htm
# [ERR] AL – Saint Clair: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Saint-Clair-County-AL.htm
# [ERR] AL – Shelby: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Shelby-County-AL.htm
# [ERR] AL – Sumter: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Sumter-County-AL.htm
# [ERR] AL – Talladega: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Talladega-County-AL.htm
# [ERR] AL – Tallapoosa: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Tallapoosa-County-AL.htm
# [ERR] AL – Tuscaloosa: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Tuscaloosa-County-AL.htm
# [ERR] AL – Walker: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Walker-County-AL.htm
# [ERR] AL – Washington: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Washington-County-AL.htm
# [ERR] AL – Winston: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Winston-County-AL.htm
# [ERR] AR – Arkansas: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Arkansas-County-AR.htm
# [ERR] AR – Ashley: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Ashley-County-AR.htm
# [ERR] AR – Baxter: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Baxter-County-AR.htm
# [ERR] AR – Benton: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Benton-County-AR.htm
# [ERR] AR – Boone: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Boone-County-AR.htm
# [ERR] AR – Bradley: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Bradley-County-AR.htm
# [ERR] AR – Carroll: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Carroll-County-AR.htm
# [ERR] AR – Chicot: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Chicot-County-AR.htm
# [ERR] AR – Clark: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Clark-County-AR.htm
# [ERR] AR – Clay: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Clay-County-AR.htm
# [ERR] AR – Cleburne: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Cleburne-County-AR.htm
# [ERR] AR – Columbia: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Columbia-County-AR.htm
# [ERR] AR – Conway: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Conway-County-AR.htm
# [ERR] AR – Craighead: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Craighead-County-AR.htm
# [ERR] AR – Crawford: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Crawford-County-AR.htm
# [ERR] AR – Crittenden: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Crittenden-County-AR.htm
# [ERR] AR – Cross: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Cross-County-AR.htm
# [ERR] AR – Dallas: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Dallas-County-AR.htm
# [ERR] AR – Desha: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Desha-County-AR.htm
# [ERR] AR – Drew: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Drew-County-AR.htm
# [ERR] AR – Faulkner: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Faulkner-County-AR.htm
# [ERR] AR – Franklin: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Franklin-County-AR.htm
# [ERR] AR – Fulton: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Fulton-County-AR.htm
# [ERR] AR – Garland: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Garland-County-AR.htm
# [ERR] AR – Greene: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Greene-County-AR.htm
# [ERR] AR – Hempstead: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Hempstead-County-AR.htm
# [ERR] AR – Hot Spring: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Hot-Spring-County-AR.htm
# [ERR] AR – Howard: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Howard-County-AR.htm
# [ERR] AR – Independence: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Independence-County-AR.htm
# [ERR] AR – Jackson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Jackson-County-AR.htm
# [ERR] AR – Jefferson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Jefferson-County-AR.htm
# [ERR] AR – Johnson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Johnson-County-AR.htm
# [ERR] AR – Lawrence: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lawrence-County-AR.htm
# [ERR] AR – Little River: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Little-River-County-AR.htm
# [ERR] AR – Logan: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Logan-County-AR.htm
# [ERR] AR – Mississippi: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Mississippi-County-AR.htm
# [ERR] AR – Ouachita: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Ouachita-County-AR.htm
# [ERR] AR – Phillips: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Phillips-County-AR.htm
# [ERR] AR – Polk: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Polk-County-AR.htm
# [ERR] AR – Pope: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pope-County-AR.htm
# [ERR] AR – Pulaski: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pulaski-County-AR.htm
# [ERR] AR – Randolph: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Randolph-County-AR.htm
# [ERR] AR – Saint Francis: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Saint-Francis-County-AR.htm
# [ERR] AR – Saline: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Saline-County-AR.htm
# [ERR] AR – Scott: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Scott-County-AR.htm
# [ERR] AR – Sebastian: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Sebastian-County-AR.htm
# [ERR] AR – Sevier: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Sevier-County-AR.htm
# [ERR] AR – Stone: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Stone-County-AR.htm
# [ERR] AR – Union: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Union-County-AR.htm
# [ERR] AR – Van Buren: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Van-Buren-County-AR.htm
# [ERR] AR – Washington: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Washington-County-AR.htm
# [ERR] AR – White: 404 Client Error: Not Found for url: https://www.hospitalstats.org/White-County-AR.htm
# [ERR] AR – Yell: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Yell-County-AR.htm
# [ERR] AZ – Apache: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Apache-County-AZ.htm
# [ERR] AZ – Cochise: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Cochise-County-AZ.htm
# [ERR] AZ – Coconino: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Coconino-County-AZ.htm
# [ERR] AZ – Gila: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Gila-County-AZ.htm
# [ERR] AZ – Graham: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Graham-County-AZ.htm
# [ERR] AZ – La Paz: 404 Client Error: Not Found for url: https://www.hospitalstats.org/La-Paz-County-AZ.htm
# [ERR] AZ – Maricopa: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Maricopa-County-AZ.htm
# [ERR] AZ – Mohave: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Mohave-County-AZ.htm
# [ERR] AZ – Navajo: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Navajo-County-AZ.htm
# [ERR] AZ – Pima: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pima-County-AZ.htm
# [ERR] AZ – Pinal: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pinal-County-AZ.htm
# [ERR] AZ – Santa Cruz: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Santa-Cruz-County-AZ.htm
# [ERR] AZ – Yavapai: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Yavapai-County-AZ.htm
# [ERR] AZ – Yuma: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Yuma-County-AZ.htm
# [ERR] CA – Alameda: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Alameda-County-CA.htm
# [ERR] CA – Amador: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Amador-County-CA.htm
# [ERR] CA – Butte: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Butte-County-CA.htm
# [ERR] CA – Calaveras: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Calaveras-County-CA.htm
# [ERR] CA – Colusa: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Colusa-County-CA.htm
# [ERR] CA – Contra Costa: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Contra-Costa-County-CA.htm
# [ERR] CA – Del Norte: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Del-Norte-County-CA.htm
# [ERR] CA – El Dorado: 404 Client Error: Not Found for url: https://www.hospitalstats.org/El-Dorado-County-CA.htm
# [ERR] CA – Fresno: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Fresno-County-CA.htm
# [ERR] CA – Glenn: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Glenn-County-CA.htm
# [ERR] CA – Humboldt: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Humboldt-County-CA.htm
# [ERR] CA – Imperial: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Imperial-County-CA.htm
# [ERR] CA – Inyo: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Inyo-County-CA.htm
# [ERR] CA – Kern: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Kern-County-CA.htm
# [ERR] CA – Kings: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Kings-County-CA.htm
# [ERR] CA – Lake: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lake-County-CA.htm
# [ERR] CA – Lassen: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lassen-County-CA.htm
# [ERR] CA – Los Angeles: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Los-Angeles-County-CA.htm
# [ERR] CA – Madera: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Madera-County-CA.htm
# [ERR] CA – Marin: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Marin-County-CA.htm
# [ERR] CA – Mariposa: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Mariposa-County-CA.htm
# [ERR] CA – Mendocino: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Mendocino-County-CA.htm
# [ERR] CA – Merced: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Merced-County-CA.htm
# [ERR] CA – Modoc: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Modoc-County-CA.htm
# [ERR] CA – Mono: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Mono-County-CA.htm
# [ERR] CA – Monterey: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Monterey-County-CA.htm
# [ERR] CA – Napa: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Napa-County-CA.htm
# [ERR] CA – Nevada: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Nevada-County-CA.htm
# [ERR] CA – Orange: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Orange-County-CA.htm
# [ERR] CA – Placer: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Placer-County-CA.htm
# [ERR] CA – Plumas: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Plumas-County-CA.htm
# [ERR] CA – Riverside: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Riverside-County-CA.htm
# [ERR] CA – Sacramento: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Sacramento-County-CA.htm
# [ERR] CA – San Benito: 404 Client Error: Not Found for url: https://www.hospitalstats.org/San-Benito-County-CA.htm
# [ERR] CA – San Bernardino: 404 Client Error: Not Found for url: https://www.hospitalstats.org/San-Bernardino-County-CA.htm
# [ERR] CA – San Diego: 404 Client Error: Not Found for url: https://www.hospitalstats.org/San-Diego-County-CA.htm
# [ERR] CA – San Francisco: 404 Client Error: Not Found for url: https://www.hospitalstats.org/San-Francisco-County-CA.htm
# [ERR] CA – San Joaquin: 404 Client Error: Not Found for url: https://www.hospitalstats.org/San-Joaquin-County-CA.htm
# [ERR] CA – San Luis Obispo: 404 Client Error: Not Found for url: https://www.hospitalstats.org/San-Luis-Obispo-County-CA.htm
# [ERR] CA – San Mateo: 404 Client Error: Not Found for url: https://www.hospitalstats.org/San-Mateo-County-CA.htm
# [ERR] CA – Santa Barbara: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Santa-Barbara-County-CA.htm
# [ERR] CA – Santa Clara: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Santa-Clara-County-CA.htm
# [ERR] CA – Santa Cruz: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Santa-Cruz-County-CA.htm
# [ERR] CA – Shasta: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Shasta-County-CA.htm
# [ERR] CA – Siskiyou: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Siskiyou-County-CA.htm
# [ERR] CA – Solano: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Solano-County-CA.htm
# [ERR] CA – Sonoma: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Sonoma-County-CA.htm
# [ERR] CA – Stanislaus: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Stanislaus-County-CA.htm
# [ERR] CA – Sutter: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Sutter-County-CA.htm
# [ERR] CA – Tehama: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Tehama-County-CA.htm
# [ERR] CA – Trinity: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Trinity-County-CA.htm
# [ERR] CA – Tulare: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Tulare-County-CA.htm
# [ERR] CA – Tuolumne: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Tuolumne-County-CA.htm
# [ERR] CA – Ventura: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Ventura-County-CA.htm
# [ERR] CA – Yolo: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Yolo-County-CA.htm
# [ERR] CA – Yuba: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Yuba-County-CA.htm
# [ERR] CO – Adams: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Adams-County-CO.htm
# [ERR] CO – Alamosa: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Alamosa-County-CO.htm
# [ERR] CO – Arapahoe: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Arapahoe-County-CO.htm
# [ERR] CO – Archuleta: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Archuleta-County-CO.htm
# [ERR] CO – Baca: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Baca-County-CO.htm
# [ERR] CO – Boulder: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Boulder-County-CO.htm
# [ERR] CO – Chaffee: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Chaffee-County-CO.htm
# [ERR] CO – Cheyenne: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Cheyenne-County-CO.htm
# [ERR] CO – Delta: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Delta-County-CO.htm
# [ERR] CO – Denver: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Denver-County-CO.htm
# [ERR] CO – Douglas: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Douglas-County-CO.htm
# [ERR] CO – Eagle: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Eagle-County-CO.htm
# [ERR] CO – El Paso: 404 Client Error: Not Found for url: https://www.hospitalstats.org/El-Paso-County-CO.htm
# [ERR] CO – Fremont: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Fremont-County-CO.htm
# [ERR] CO – Garfield: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Garfield-County-CO.htm
# [ERR] CO – Gunnison: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Gunnison-County-CO.htm
# [ERR] CO – Huerfano: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Huerfano-County-CO.htm
# [ERR] CO – Jefferson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Jefferson-County-CO.htm
# [ERR] CO – Kit Carson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Kit-Carson-County-CO.htm
# [ERR] CO – La Plata: 404 Client Error: Not Found for url: https://www.hospitalstats.org/La-Plata-County-CO.htm
# [ERR] CO – Lake: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lake-County-CO.htm
# [ERR] CO – Larimer: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Larimer-County-CO.htm
# [ERR] CO – Las Animas: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Las-Animas-County-CO.htm
# [ERR] CO – Logan: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Logan-County-CO.htm
# [ERR] CO – Mesa: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Mesa-County-CO.htm
# [ERR] CO – Montezuma: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Montezuma-County-CO.htm
# [ERR] CO – Montrose: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Montrose-County-CO.htm
# [ERR] CO – Morgan: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Morgan-County-CO.htm
# [ERR] CO – Otero: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Otero-County-CO.htm
# [ERR] CO – Phillips: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Phillips-County-CO.htm
# [ERR] CO – Pitkin: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pitkin-County-CO.htm
# [ERR] CO – Prowers: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Prowers-County-CO.htm
# [ERR] CO – Pueblo: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pueblo-County-CO.htm
# [ERR] CO – Rio Blanco: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Rio-Blanco-County-CO.htm
# [ERR] CO – Rio Grande: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Rio-Grande-County-CO.htm
# [ERR] CO – Routt: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Routt-County-CO.htm
# [ERR] CO – Summit: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Summit-County-CO.htm
# [ERR] CO – Teller: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Teller-County-CO.htm
# [ERR] CO – Weld: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Weld-County-CO.htm
# [ERR] CO – Yuma: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Yuma-County-CO.htm
# [ERR] CT – Fairfield: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Fairfield-County-CT.htm
# [ERR] CT – Hartford: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Hartford-County-CT.htm
# [ERR] CT – Litchfield: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Litchfield-County-CT.htm
# [ERR] CT – Middlesex: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Middlesex-County-CT.htm
# [ERR] CT – New Haven: 404 Client Error: Not Found for url: https://www.hospitalstats.org/New-Haven-County-CT.htm
# [ERR] CT – New London: 404 Client Error: Not Found for url: https://www.hospitalstats.org/New-London-County-CT.htm
# [ERR] CT – Tolland: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Tolland-County-CT.htm
# [ERR] CT – Windham: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Windham-County-CT.htm
# [ERR] DE – Kent: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Kent-County-DE.htm
# [ERR] DE – New Castle: 404 Client Error: Not Found for url: https://www.hospitalstats.org/New-Castle-County-DE.htm
# [ERR] DE – Sussex: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Sussex-County-DE.htm
# [ERR] FL – Alachua: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Alachua-County-FL.htm
# [ERR] FL – Bay: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Bay-County-FL.htm
# [ERR] FL – Bradford: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Bradford-County-FL.htm
# [ERR] FL – Brevard: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Brevard-County-FL.htm
# [ERR] FL – Broward: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Broward-County-FL.htm
# [ERR] FL – Charlotte: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Charlotte-County-FL.htm
# [ERR] FL – Citrus: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Citrus-County-FL.htm
# [ERR] FL – Clay: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Clay-County-FL.htm
# [ERR] FL – Collier: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Collier-County-FL.htm
# [ERR] FL – Columbia: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Columbia-County-FL.htm
# [ERR] FL – De Soto: 404 Client Error: Not Found for url: https://www.hospitalstats.org/De-Soto-County-FL.htm
# [ERR] FL – Duval: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Duval-County-FL.htm
# [ERR] FL – Escambia: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Escambia-County-FL.htm
# [ERR] FL – Flagler: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Flagler-County-FL.htm
# [ERR] FL – Franklin: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Franklin-County-FL.htm
# [ERR] FL – Gulf: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Gulf-County-FL.htm
# [ERR] FL – Hardee: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Hardee-County-FL.htm
# [ERR] FL – Hendry: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Hendry-County-FL.htm
# [ERR] FL – Hernando: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Hernando-County-FL.htm
# [ERR] FL – Highlands: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Highlands-County-FL.htm
# [ERR] FL – Hillsborough: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Hillsborough-County-FL.htm
# [ERR] FL – Holmes: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Holmes-County-FL.htm
# [ERR] FL – Indian River: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Indian-River-County-FL.htm
# [ERR] FL – Jackson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Jackson-County-FL.htm
# [ERR] FL – Lake: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lake-County-FL.htm
# [ERR] FL – Lee: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lee-County-FL.htm
# [ERR] FL – Leon: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Leon-County-FL.htm
# [ERR] FL – Levy: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Levy-County-FL.htm
# [ERR] FL – Madison: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Madison-County-FL.htm
# [ERR] FL – Manatee: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Manatee-County-FL.htm
# [ERR] FL – Marion: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Marion-County-FL.htm
# [ERR] FL – Martin: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Martin-County-FL.htm
# [ERR] FL – Miami-Dade: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Miami-Dade-County-FL.htm
# [ERR] FL – Monroe: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Monroe-County-FL.htm
# [ERR] FL – Nassau: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Nassau-County-FL.htm
# [ERR] FL – Okaloosa: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Okaloosa-County-FL.htm
# [ERR] FL – Okeechobee: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Okeechobee-County-FL.htm
# [ERR] FL – Orange: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Orange-County-FL.htm
# [ERR] FL – Osceola: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Osceola-County-FL.htm
# [ERR] FL – Palm Beach: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Palm-Beach-County-FL.htm
# [ERR] FL – Pasco: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pasco-County-FL.htm
# [ERR] FL – Pinellas: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pinellas-County-FL.htm
# [ERR] FL – Polk: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Polk-County-FL.htm
# [ERR] FL – Putnam: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Putnam-County-FL.htm
# [ERR] FL – Saint Johns: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Saint-Johns-County-FL.htm
# [ERR] FL – Saint Lucie: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Saint-Lucie-County-FL.htm
# [ERR] FL – Santa Rosa: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Santa-Rosa-County-FL.htm
# [ERR] FL – Sarasota: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Sarasota-County-FL.htm
# [ERR] FL – Seminole: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Seminole-County-FL.htm
# [ERR] FL – Sumter: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Sumter-County-FL.htm
# [ERR] FL – Suwannee: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Suwannee-County-FL.htm
# [ERR] FL – Taylor: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Taylor-County-FL.htm
# [ERR] FL – Union: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Union-County-FL.htm
# [ERR] FL – Volusia: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Volusia-County-FL.htm
# [ERR] FL – Walton: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Walton-County-FL.htm
# [ERR] FL – Washington: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Washington-County-FL.htm
# [ERR] GA – Appling: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Appling-County-GA.htm
# [ERR] GA – Bacon: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Bacon-County-GA.htm
# [ERR] GA – Baldwin: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Baldwin-County-GA.htm
# [ERR] GA – Barrow: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Barrow-County-GA.htm
# [ERR] GA – Bartow: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Bartow-County-GA.htm
# [ERR] GA – Ben Hill: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Ben-Hill-County-GA.htm
# [ERR] GA – Berrien: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Berrien-County-GA.htm
# [ERR] GA – Bibb: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Bibb-County-GA.htm
# [ERR] GA – Bleckley: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Bleckley-County-GA.htm
# [ERR] GA – Brooks: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Brooks-County-GA.htm
# [ERR] GA – Bulloch: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Bulloch-County-GA.htm
# [ERR] GA – Burke: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Burke-County-GA.htm
# [ERR] GA – Butts: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Butts-County-GA.htm
# [ERR] GA – Camden: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Camden-County-GA.htm
# [ERR] GA – Candler: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Candler-County-GA.htm
# [ERR] GA – Carroll: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Carroll-County-GA.htm
# [ERR] GA – Catoosa: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Catoosa-County-GA.htm
# [ERR] GA – Charlton: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Charlton-County-GA.htm
# [ERR] GA – Chatham: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Chatham-County-GA.htm
# [ERR] GA – Chattooga: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Chattooga-County-GA.htm
# [ERR] GA – Cherokee: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Cherokee-County-GA.htm
# [ERR] GA – Clarke: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Clarke-County-GA.htm
# [ERR] GA – Clayton: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Clayton-County-GA.htm
# [ERR] GA – Clinch: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Clinch-County-GA.htm
# [ERR] GA – Cobb: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Cobb-County-GA.htm
# [ERR] GA – Coffee: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Coffee-County-GA.htm
# [ERR] GA – Colquitt: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Colquitt-County-GA.htm
# [ERR] GA – Cook: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Cook-County-GA.htm
# [ERR] GA – Coweta: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Coweta-County-GA.htm
# [ERR] GA – Crisp: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Crisp-County-GA.htm
# [ERR] GA – Decatur: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Decatur-County-GA.htm
# [ERR] GA – Dekalb: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Dekalb-County-GA.htm
# [ERR] GA – Dodge: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Dodge-County-GA.htm
# [ERR] GA – Dougherty: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Dougherty-County-GA.htm
# [ERR] GA – Douglas: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Douglas-County-GA.htm
# [ERR] GA – Early: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Early-County-GA.htm
# [ERR] GA – Effingham: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Effingham-County-GA.htm
# [ERR] GA – Elbert: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Elbert-County-GA.htm
# [ERR] GA – Emanuel: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Emanuel-County-GA.htm
# [ERR] GA – Evans: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Evans-County-GA.htm
# [ERR] GA – Fannin: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Fannin-County-GA.htm
# [ERR] GA – Floyd: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Floyd-County-GA.htm
# [ERR] GA – Forsyth: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Forsyth-County-GA.htm
# [ERR] GA – Franklin: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Franklin-County-GA.htm
# [ERR] GA – Fulton: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Fulton-County-GA.htm
# [ERR] GA – Gilmer: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Gilmer-County-GA.htm
# [ERR] GA – Glynn: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Glynn-County-GA.htm
# [ERR] GA – Gordon: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Gordon-County-GA.htm
# [ERR] GA – Grady: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Grady-County-GA.htm
# [ERR] GA – Greene: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Greene-County-GA.htm
# [ERR] GA – Gwinnett: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Gwinnett-County-GA.htm
# [ERR] GA – Habersham: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Habersham-County-GA.htm
# [ERR] GA – Hall: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Hall-County-GA.htm
# [ERR] GA – Haralson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Haralson-County-GA.htm
# [ERR] GA – Henry: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Henry-County-GA.htm
# [ERR] GA – Houston: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Houston-County-GA.htm
# [ERR] GA – Irwin: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Irwin-County-GA.htm
# [ERR] GA – Jackson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Jackson-County-GA.htm
# [ERR] GA – Jasper: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Jasper-County-GA.htm
# [ERR] GA – Jeff Davis: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Jeff-Davis-County-GA.htm
# [ERR] GA – Jefferson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Jefferson-County-GA.htm
# [ERR] GA – Lanier: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lanier-County-GA.htm
# [ERR] GA – Laurens: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Laurens-County-GA.htm
# [ERR] GA – Liberty: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Liberty-County-GA.htm
# [ERR] GA – Lowndes: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lowndes-County-GA.htm
# [ERR] GA – Lumpkin: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lumpkin-County-GA.htm
# [ERR] GA – Macon: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Macon-County-GA.htm
# [ERR] GA – Mcduffie: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Mcduffie-County-GA.htm
# [ERR] GA – Meriwether: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Meriwether-County-GA.htm
# [ERR] GA – Miller: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Miller-County-GA.htm
# [ERR] GA – Mitchell: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Mitchell-County-GA.htm
# [ERR] GA – Monroe: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Monroe-County-GA.htm
# [ERR] GA – Morgan: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Morgan-County-GA.htm
# [ERR] GA – Murray: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Murray-County-GA.htm
# [ERR] GA – Muscogee: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Muscogee-County-GA.htm
# [ERR] GA – Newton: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Newton-County-GA.htm
# [ERR] GA – Paulding: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Paulding-County-GA.htm
# [ERR] GA – Peach: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Peach-County-GA.htm
# [ERR] GA – Pickens: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pickens-County-GA.htm
# [ERR] GA – Polk: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Polk-County-GA.htm
# [ERR] GA – Pulaski: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pulaski-County-GA.htm
# [ERR] GA – Putnam: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Putnam-County-GA.htm
# [ERR] GA – Rabun: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Rabun-County-GA.htm
# [ERR] GA – Randolph: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Randolph-County-GA.htm
# [ERR] GA – Richmond: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Richmond-County-GA.htm
# [ERR] GA – Rockdale: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Rockdale-County-GA.htm
# [ERR] GA – Seminole: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Seminole-County-GA.htm
# [ERR] GA – Spalding: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Spalding-County-GA.htm
# [ERR] GA – Stephens: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Stephens-County-GA.htm
# [ERR] GA – Stewart: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Stewart-County-GA.htm
# [ERR] GA – Sumter: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Sumter-County-GA.htm
# [ERR] GA – Thomas: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Thomas-County-GA.htm
# [ERR] GA – Tift: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Tift-County-GA.htm
# [ERR] GA – Toombs: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Toombs-County-GA.htm
# [ERR] GA – Towns: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Towns-County-GA.htm
# [ERR] GA – Troup: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Troup-County-GA.htm
# [ERR] GA – Union: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Union-County-GA.htm
# [ERR] GA – Upson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Upson-County-GA.htm
# [ERR] GA – Walton: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Walton-County-GA.htm
# [ERR] GA – Ware: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Ware-County-GA.htm
# [ERR] GA – Washington: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Washington-County-GA.htm
# [ERR] GA – Wayne: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Wayne-County-GA.htm
# [ERR] GA – Wheeler: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Wheeler-County-GA.htm
# [ERR] GA – Whitfield: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Whitfield-County-GA.htm
# [ERR] GA – Wilkes: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Wilkes-County-GA.htm
# [ERR] GA – Worth: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Worth-County-GA.htm
# [ERR] HI – Hawaii: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Hawaii-County-HI.htm
# [ERR] HI – Honolulu: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Honolulu-County-HI.htm
# [ERR] HI – Kauai: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Kauai-County-HI.htm
# [ERR] HI – Maui: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Maui-County-HI.htm
# [ERR] IA – Adair: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Adair-County-IA.htm
# [ERR] IA – Adams: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Adams-County-IA.htm
# [ERR] IA – Allamakee: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Allamakee-County-IA.htm
# [ERR] IA – Appanoose: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Appanoose-County-IA.htm
# [ERR] IA – Audubon: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Audubon-County-IA.htm
# [ERR] IA – Black Hawk: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Black-Hawk-County-IA.htm
# [ERR] IA – Boone: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Boone-County-IA.htm
# [ERR] IA – Bremer: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Bremer-County-IA.htm
# [ERR] IA – Buchanan: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Buchanan-County-IA.htm
# [ERR] IA – Buena Vista: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Buena-Vista-County-IA.htm
# [ERR] IA – Calhoun: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Calhoun-County-IA.htm
# [ERR] IA – Carroll: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Carroll-County-IA.htm
# [ERR] IA – Cass: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Cass-County-IA.htm
# [ERR] IA – Cerro Gordo: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Cerro-Gordo-County-IA.htm
# [ERR] IA – Cherokee: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Cherokee-County-IA.htm
# [ERR] IA – Chickasaw: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Chickasaw-County-IA.htm
# [ERR] IA – Clarke: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Clarke-County-IA.htm
# [ERR] IA – Clay: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Clay-County-IA.htm
# [ERR] IA – Clayton: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Clayton-County-IA.htm
# [ERR] IA – Clinton: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Clinton-County-IA.htm
# [ERR] IA – Crawford: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Crawford-County-IA.htm
# [ERR] IA – Dallas: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Dallas-County-IA.htm
# [ERR] IA – Davis: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Davis-County-IA.htm
# [ERR] IA – Decatur: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Decatur-County-IA.htm
# [ERR] IA – Delaware: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Delaware-County-IA.htm
# [ERR] IA – Des Moines: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Des-Moines-County-IA.htm
# [ERR] IA – Dickinson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Dickinson-County-IA.htm
# [ERR] IA – Dubuque: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Dubuque-County-IA.htm
# ...
# [ERR] WA – King: 404 Client Error: Not Found for url: https://www.hospitalstats.org/King-County-WA.htm
# [ERR] WA – Kitsap: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Kitsap-County-WA.htm
# [ERR] WA – Kittitas: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Kittitas-County-WA.htm
# [ERR] WA – Klickitat: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Klickitat-County-WA.htm
# [ERR] WA – Lewis: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lewis-County-WA.htm
# [ERR] WA – Lincoln: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lincoln-County-WA.htm
# [ERR] WA – Mason: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Mason-County-WA.htm
# [ERR] WA – Okanogan: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Okanogan-County-WA.htm
# [ERR] WA – Pacific: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pacific-County-WA.htm
# [ERR] WA – Pend Oreille: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pend-Oreille-County-WA.htm
# [ERR] WA – Pierce: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pierce-County-WA.htm
# [ERR] WA – Skagit: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Skagit-County-WA.htm
# [ERR] WA – Snohomish: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Snohomish-County-WA.htm
# [ERR] WA – Spokane: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Spokane-County-WA.htm
# [ERR] WA – Stevens: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Stevens-County-WA.htm
# [ERR] WA – Thurston: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Thurston-County-WA.htm
# [ERR] WA – Walla Walla: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Walla-Walla-County-WA.htm
# [ERR] WA – Whatcom: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Whatcom-County-WA.htm
# [ERR] WA – Whitman: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Whitman-County-WA.htm
# [ERR] WA – Yakima: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Yakima-County-WA.htm
# [ERR] WI – Adams: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Adams-County-WI.htm
# [ERR] WI – Ashland: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Ashland-County-WI.htm
# [ERR] WI – Barron: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Barron-County-WI.htm
# [ERR] WI – Brown: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Brown-County-WI.htm
# [ERR] WI – Burnett: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Burnett-County-WI.htm
# [ERR] WI – Calumet: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Calumet-County-WI.htm
# [ERR] WI – Chippewa: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Chippewa-County-WI.htm
# [ERR] WI – Clark: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Clark-County-WI.htm
# [ERR] WI – Columbia: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Columbia-County-WI.htm
# [ERR] WI – Crawford: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Crawford-County-WI.htm
# [ERR] WI – Dane: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Dane-County-WI.htm
# [ERR] WI – Dodge: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Dodge-County-WI.htm
# [ERR] WI – Door: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Door-County-WI.htm
# [ERR] WI – Douglas: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Douglas-County-WI.htm
# [ERR] WI – Dunn: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Dunn-County-WI.htm
# [ERR] WI – Eau Claire: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Eau-Claire-County-WI.htm
# [ERR] WI – Fond Du Lac: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Fond-Du-Lac-County-WI.htm
# [ERR] WI – Grant: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Grant-County-WI.htm
# [ERR] WI – Green: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Green-County-WI.htm
# [ERR] WI – Green Lake: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Green-Lake-County-WI.htm
# [ERR] WI – Iowa: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Iowa-County-WI.htm
# [ERR] WI – Jackson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Jackson-County-WI.htm
# [ERR] WI – Jefferson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Jefferson-County-WI.htm
# [ERR] WI – Juneau: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Juneau-County-WI.htm
# [ERR] WI – Kenosha: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Kenosha-County-WI.htm
# [ERR] WI – La Crosse: 404 Client Error: Not Found for url: https://www.hospitalstats.org/La-Crosse-County-WI.htm
# [ERR] WI – Lafayette: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lafayette-County-WI.htm
# [ERR] WI – Langlade: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Langlade-County-WI.htm
# [ERR] WI – Lincoln: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lincoln-County-WI.htm
# [ERR] WI – Manitowoc: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Manitowoc-County-WI.htm
# [ERR] WI – Marathon: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Marathon-County-WI.htm
# [ERR] WI – Marinette: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Marinette-County-WI.htm
# [ERR] WI – Milwaukee: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Milwaukee-County-WI.htm
# [ERR] WI – Monroe: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Monroe-County-WI.htm
# [ERR] WI – Oconto: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Oconto-County-WI.htm
# [ERR] WI – Oneida: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Oneida-County-WI.htm
# [ERR] WI – Outagamie: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Outagamie-County-WI.htm
# [ERR] WI – Ozaukee: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Ozaukee-County-WI.htm
# [ERR] WI – Pepin: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pepin-County-WI.htm
# [ERR] WI – Pierce: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pierce-County-WI.htm
# [ERR] WI – Polk: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Polk-County-WI.htm
# [ERR] WI – Portage: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Portage-County-WI.htm
# [ERR] WI – Price: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Price-County-WI.htm
# [ERR] WI – Racine: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Racine-County-WI.htm
# [ERR] WI – Richland: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Richland-County-WI.htm
# [ERR] WI – Rock: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Rock-County-WI.htm
# [ERR] WI – Rusk: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Rusk-County-WI.htm
# [ERR] WI – Saint Croix: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Saint-Croix-County-WI.htm
# [ERR] WI – Sauk: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Sauk-County-WI.htm
# [ERR] WI – Sawyer: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Sawyer-County-WI.htm
# [ERR] WI – Shawano: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Shawano-County-WI.htm
# [ERR] WI – Sheboygan: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Sheboygan-County-WI.htm
# [ERR] WI – Taylor: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Taylor-County-WI.htm
# [ERR] WI – Trempealeau: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Trempealeau-County-WI.htm
# [ERR] WI – Vernon: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Vernon-County-WI.htm
# [ERR] WI – Vilas: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Vilas-County-WI.htm
# [ERR] WI – Walworth: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Walworth-County-WI.htm
# [ERR] WI – Washburn: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Washburn-County-WI.htm
# [ERR] WI – Washington: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Washington-County-WI.htm
# [ERR] WI – Waukesha: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Waukesha-County-WI.htm
# [ERR] WI – Waupaca: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Waupaca-County-WI.htm
# [ERR] WI – Waushara: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Waushara-County-WI.htm
# [ERR] WI – Winnebago: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Winnebago-County-WI.htm
# [ERR] WI – Wood: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Wood-County-WI.htm
# [ERR] WV – Barbour: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Barbour-County-WV.htm
# [ERR] WV – Berkeley: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Berkeley-County-WV.htm
# [ERR] WV – Boone: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Boone-County-WV.htm
# [ERR] WV – Braxton: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Braxton-County-WV.htm
# [ERR] WV – Cabell: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Cabell-County-WV.htm
# [ERR] WV – Calhoun: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Calhoun-County-WV.htm
# [ERR] WV – Fayette: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Fayette-County-WV.htm
# [ERR] WV – Grant: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Grant-County-WV.htm
# [ERR] WV – Greenbrier: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Greenbrier-County-WV.htm
# [ERR] WV – Hampshire: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Hampshire-County-WV.htm
# [ERR] WV – Hancock: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Hancock-County-WV.htm
# [ERR] WV – Harrison: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Harrison-County-WV.htm
# [ERR] WV – Jackson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Jackson-County-WV.htm
# [ERR] WV – Jefferson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Jefferson-County-WV.htm
# [ERR] WV – Kanawha: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Kanawha-County-WV.htm
# [ERR] WV – Lewis: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lewis-County-WV.htm
# [ERR] WV – Logan: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Logan-County-WV.htm
# [ERR] WV – Marion: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Marion-County-WV.htm
# [ERR] WV – Marshall: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Marshall-County-WV.htm
# [ERR] WV – Mason: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Mason-County-WV.htm
# [ERR] WV – Mcdowell: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Mcdowell-County-WV.htm
# [ERR] WV – Mercer: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Mercer-County-WV.htm
# [ERR] WV – Mineral: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Mineral-County-WV.htm
# [ERR] WV – Mingo: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Mingo-County-WV.htm
# [ERR] WV – Monongalia: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Monongalia-County-WV.htm
# [ERR] WV – Morgan: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Morgan-County-WV.htm
# [ERR] WV – Nicholas: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Nicholas-County-WV.htm
# [ERR] WV – Ohio: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Ohio-County-WV.htm
# [ERR] WV – Pocahontas: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Pocahontas-County-WV.htm
# [ERR] WV – Preston: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Preston-County-WV.htm
# [ERR] WV – Putnam: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Putnam-County-WV.htm
# [ERR] WV – Raleigh: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Raleigh-County-WV.htm
# [ERR] WV – Randolph: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Randolph-County-WV.htm
# [ERR] WV – Roane: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Roane-County-WV.htm
# [ERR] WV – Summers: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Summers-County-WV.htm
# [ERR] WV – Taylor: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Taylor-County-WV.htm
# [ERR] WV – Tyler: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Tyler-County-WV.htm
# [ERR] WV – Upshur: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Upshur-County-WV.htm
# [ERR] WV – Webster: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Webster-County-WV.htm
# [ERR] WV – Wetzel: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Wetzel-County-WV.htm
# [ERR] WV – Wood: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Wood-County-WV.htm
# [ERR] WY – Albany: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Albany-County-WY.htm
# [ERR] WY – Big Horn: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Big-Horn-County-WY.htm
# [ERR] WY – Campbell: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Campbell-County-WY.htm
# [ERR] WY – Carbon: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Carbon-County-WY.htm
# [ERR] WY – Converse: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Converse-County-WY.htm
# [ERR] WY – Crook: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Crook-County-WY.htm
# [ERR] WY – Fremont: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Fremont-County-WY.htm
# [ERR] WY – Goshen: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Goshen-County-WY.htm
# [ERR] WY – Hot Springs: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Hot-Springs-County-WY.htm
# [ERR] WY – Johnson: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Johnson-County-WY.htm
# [ERR] WY – Laramie: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Laramie-County-WY.htm
# [ERR] WY – Lincoln: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Lincoln-County-WY.htm
# [ERR] WY – Natrona: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Natrona-County-WY.htm
# [ERR] WY – Niobrara: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Niobrara-County-WY.htm
# [ERR] WY – Park: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Park-County-WY.htm
# [ERR] WY – Platte: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Platte-County-WY.htm
# [ERR] WY – Sheridan: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Sheridan-County-WY.htm
# [ERR] WY – Sweetwater: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Sweetwater-County-WY.htm
# [ERR] WY – Teton: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Teton-County-WY.htm
# [ERR] WY – Uinta: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Uinta-County-WY.htm
# [ERR] WY – Washakie: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Washakie-County-WY.htm
# [ERR] WY – Weston: 404 Client Error: Not Found for url: https://www.hospitalstats.org/Weston-County-WY.htm

# %%
if county_frames:
    df_all_united_states_hospitals = pd.concat(
        [v for v in county_frames.values() if v is not None],
        ignore_index=True
    )
else:
    df_all_united_states_hospitals = pd.DataFrame()

print("All United States hospitals:", df_all_united_states_hospitals.shape)
if not df_all_united_states_hospitals.empty:
    if "detail_error" in df_all_united_states_hospitals.columns:
        df_all_united_states_hospitals = df_all_united_states_hospitals[
            df_all_united_states_hospitals["detail_error"].isna() | (df_all_united_states_hospitals["detail_error"] == "")
        ].drop(columns=["detail_error"])
    if "hospital" in df_all_united_states_hospitals.columns:
        df_all_united_states_hospitals = df_all_united_states_hospitals[
            df_all_united_states_hospitals["hospital"].notna() & (df_all_united_states_hospitals["hospital"].astype(str).str.strip() != "")
        ].reset_index(drop=True)
df_all_united_states_hospitals.head(20)
#export as a CSV
df_all_united_states_hospitals.to_csv("united_states_hospitals_enriched.csv", index=False)
# Out:
# All United States hospitals: (0, 0)
